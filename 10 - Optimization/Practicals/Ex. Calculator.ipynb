# %% [markdown]
# # Exercises calculator

# %% [markdown]
# **No more than two pages for the answers of the 3 problems!!**

# %%
N = 21287070      # My NIUB number

r_p = N % 13
if r_p==0:
  r=2
if r_p==1:
  r=2
else:
  r=r_p

print("You should do exercises: 13, " + str(r) + ", " + str((r+7)%13))
# Out:
# You should do exercises: 13, 12, 6

# %%
N = 21287070      # My NIUB number

r_p = N % 16
r = r_p+1
print(r)

print("You should do exercises: " + str(r) + ", " + str((r+5)%16) + ", " + str((r+10)%16))
# Out:
# 15
# You should do exercises: 15, 4, 9
