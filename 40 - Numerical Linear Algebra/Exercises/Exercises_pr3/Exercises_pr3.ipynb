# %% [markdown]
# # Ex.1 - Banded Systems - Answer

# %%
import numpy as np

n = 6

def isbanded(A, ub, lb, tol):   #Sta funzione non capisco che senso abbia, controlla solo i valori dati di ub e lb, sarebbe meglio scriverne una che ritorni direttamente la bandwith... come già esiste

  for i in range(0,n):
    for j in range(0,max(-lb+i,0)):
      if abs()    #La sua versione per controllare se è maggiore o minore di zero usando una sensibilità per evitare errori (credo)

# %% [markdown]
# # Ex. 2 - Banded Systems - Answer
