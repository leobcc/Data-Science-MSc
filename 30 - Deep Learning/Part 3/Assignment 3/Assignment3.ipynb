# %% [markdown]
# # Assignment 3: Attention
#
# The objectives of this assignment are:
#
# + To implement Bahdanau Attention and Luong General Attention classes.
# + To do a comparative (# of steps to converge, test error) of the three methods we have seen. Use these values for the comparative (the training datset size and `rnn_units` and `batch_size` values are up to you):
#     + `n_timesteps_in = 100`
#     + `n_features = 20`.
# + To implement a function to visualize the attention weights for one example. You can visualize them as in this figure (that corresponds to a machine translation task):
#
# <div>
# <center>
# <img src="https://jalammar.github.io/images/attention_sentence.png" width="200">
# </center>
# </div>
#
# + To write a blog entry explaining in your words how does attention work. You can do it in your favourite blog site. If you do not have a favourite blog site, you can start one here: https://hackmd.io/
#
# You have to report all your work at the end of this notebook.

# %% [markdown]
# # Code

# %%
#@title Some utils
from random import randint
from matplotlib import pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

import numpy as np

def generate_sequence(length, n_unique):
    """
    Generate a sequence of random integers.
    
    :length: Total length of the generated sequence
    :n_unique: Maximum number allowed
    """
    return [randint(1, n_unique-1) for _ in range(length)]

def one_hot_encode(sequence, n_unique):
    """
    Transform a sequence of integers into a one-hot-encoding vector
    
    :sequence: The sequence we want to transform
    :n_unique: Maximum number allowed (length of the one-hot-encoded vector)
    """
    encoding = list()
    for value in sequence:
        vector = [0 for _ in range(n_unique)]
        vector[value] = 1
        encoding.append(vector)
    return np.array(encoding)

def one_hot_decode(encoded_seq):
    """
    Transorm a one-hot-encoded vector into a list of integers
    
    :encoded_seq: One hot encoded sequence to be transformed
    """
    return [np.argmax(vector) for vector in encoded_seq]


def get_reversed_pairs(time_steps,vocabulary_size):
    """
    Generate a pair X, y where y is the 'reversed' version of X.
    
    :time_steps: Sequence length
    :vocabulary_size: Maximum number allowed
    """
    # generate random sequence and reverse it
    sequence_in = generate_sequence(time_steps, vocabulary_size)
    sequence_out = sequence_in[::-1]

    # one hot encode both sequences
    X = one_hot_encode(sequence_in, vocabulary_size)
    y = one_hot_encode(sequence_out, vocabulary_size)
    
    # reshape as 3D so it can be inputed to the LSTM
    X = X.reshape((1, X.shape[0], X.shape[1]))
    y = y.reshape((1, y.shape[0], y.shape[1]))
    return X,y


def create_dataset(train_size, test_size, time_steps,vocabulary_size):
    """
    Generates a datset of reversed pairs X, y.
    
    :train_size: Number of train pairs
    :test_size: Number of test pairs
    :time_steps: Sequence length
    :vocabulary_size: Maximum number allowed
    """
    
    # Generate reversed pairs for training
    pairs = [get_reversed_pairs(time_steps,vocabulary_size) for _ in range(train_size)]
    pairs= np.array(pairs).squeeze()
    X_train = pairs[:,0]
    y_train = pairs[:,1]
    
    # Generate reversed pairs for test
    pairs = [get_reversed_pairs(time_steps,vocabulary_size) for _ in range(test_size)]
    pairs= np.array(pairs).squeeze()
    X_test = pairs[:,0]
    y_test = pairs[:,1]	

    return X_train, y_train, X_test, y_test


def train_test(model, X_train, y_train , X_test, y_test, epochs=500, batch_size=32, patience=5):
    """
    It trains a model and evaluates the result on the test dataset
    
    :model: Model to be fit
    :X_train, y_train: Train samples and labels 
    :X_test y_test: Test samples and labels 
    :epochs: Maximum number of iterations that the model will perform
    :batch_size: Samples per batch
    :patience: Number of rounds without improvement that the model can perform. If there is no improvement on the loss, it will stop the trainning process.
    """
    
    # Train the model
    history=model.fit(X_train, y_train, 
                      validation_split= 0.1, 
                      epochs=epochs,
                      batch_size=batch_size, 
                      callbacks=[EarlyStopping(monitor='val_loss', patience=patience, restore_best_weights=True)])
    
    _, train_acc = model.evaluate(X_train, y_train, batch_size=batch_size)
    _, test_acc = model.evaluate(X_test, y_test, batch_size=batch_size)
    
    print('\nPREDICTION ACCURACY (%):')
    print('Train: %.3f, Test: %.3f' % (train_acc*100, test_acc*100))
    
    fig, axs = plt.subplots(1,2, figsize=(12,5))
    # summarize history for loss
    axs[0].plot(history.history['loss'])
    axs[0].plot(history.history['val_loss'])
    axs[0].set_title(model.name+' loss')
    axs[0].set_ylabel('loss')
    axs[0].set_xlabel('epoch')
    axs[0].legend(['train', 'val'], loc='upper left')
    
    # summarize history for accuracy
    axs[1].plot(history.history['accuracy'])
    axs[1].plot(history.history['val_accuracy'])
    axs[1].set_title(model.name+' accuracy')
    axs[1].set_ylabel('accuracy')
    axs[1].set_xlabel('epoch')
    axs[1].legend(['train', 'val'], loc='upper left')
    plt.show()
    
    
def predict(model, n_timesteps_in,n_features, x, y_real=None, ):
    pred=model.predict(x.reshape(1,n_timesteps_in,n_features), batch_size=1)
    print('input', one_hot_decode(x))    
    print('predicted', one_hot_decode(pred[0]))
    if y_real is not None:
        print('expected', one_hot_decode(y_real))

# %%
import tensorflow as tf
import numpy as np

from tensorflow.keras.layers import Input, Dense, LSTM, Lambda
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

tf.keras.backend.set_floatx('float64')

#attention model
def build_attention_model(attention, batch_size, rnn_units):
    
    # ENCODER STEP
    # ------------
    # Same encoder as before with one and only difference. Now we need all the lstm states so we
    # set return_sequences=True and return_state=True.
    encoder_inputs = Input(shape=(n_timesteps_in, n_features), name='encoder_inputs')
    encoder_lstm = LSTM(rnn_units, return_sequences=True, return_state=True, name='encoder_lstm')
    encoder_outputs, encoder_state_h, encoder_state_c = encoder_lstm(encoder_inputs)
    
    states = [encoder_state_h, encoder_state_c]
    
    # DECODER STEP
    # ------------
    # Set up the decoder layers
    # input shape: (1, n_features + rnn_units)
    decoder_lstm = LSTM(rnn_units, return_state=True, name='decoder_lstm')
    decoder_dense = Dense(n_features, activation='softmax', name='decoder_dense')
    
    # As before, we use as first input the 0-sequence
    all_outputs = []
    inputs = np.zeros((batch_size, 1, n_features))
    
    # Decoder_outputs is the last hidden state of the encoder. Encoder_outputs are all the states
    decoder_outputs = encoder_state_h
    
    # Decoder will only process one time step at a time.
    for _ in range(n_timesteps_in):

        # Pay attention!
        # decoder_outputs (last hidden state) + encoder_outputs (all hidden states)
        context_vector, attention_weights = attention(decoder_outputs, encoder_outputs)
        context_vector = tf.expand_dims(context_vector, 1)

        # create the context vector by applying attention to 
        # Concatenate the input + context vectore to find the next decoder's input
        inputs = tf.concat([context_vector, inputs], axis=-1)

        # Passing the concatenated vector to the LSTM
        # Run the decoder on one timestep with attended input and previous states
        decoder_outputs, state_h, state_c = decoder_lstm(inputs, initial_state=states)        
        outputs = decoder_dense(decoder_outputs)
        
        # Use the last hidden state for prediction the output
        # save the current prediction
        # we will concatenate all predictions later
        outputs = tf.expand_dims(outputs, 1)
        all_outputs.append(outputs)
        
        # Reinject the output (prediction) as inputs for the next loop iteration
        # as well as update the states
        inputs = outputs
        states = [state_h, state_c]
        
    decoder_outputs = Lambda(lambda x: K.concatenate(x, axis=1))(all_outputs)
    model = Model(encoder_inputs, decoder_outputs, name='model_encoder_decoder')
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    
    return model, encoder_lstm, decoder_lstm, decoder_dense


class LuongDotAttention(tf.keras.layers.Layer):
    def __init__(self):
        super(LuongDotAttention, self).__init__()

    def call(self, query, values):
        query_with_time_axis = tf.expand_dims(query, 1)
        values_transposed = tf.transpose(values, perm=[0, 2, 1])

        # LUONGH Dot-product
        score = tf.transpose(tf.matmul(query_with_time_axis, 
                                       values_transposed), perm=[0, 2, 1])

        # attention_weights shape == (batch_size, max_length, 1)
        attention_weights = tf.nn.softmax(score, axis=1)
        
        # context_vector shape after sum == (batch_size, hidden_size)
        context_vector = attention_weights * values
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %%
# dataset 
n_timesteps_in = 100  # Sequence length
n_features = 20     # Maximum number allowed-1 (length of the one-hot-encoded vector)
train_size = 2000 
test_size = 200
X_train, y_train, X_test, y_test = create_dataset(train_size, test_size, n_timesteps_in,n_features )

# training parameters
batch_size = 100

# model parameters
rnn_units = 100

# attention model
attention = LuongDotAttention()
model_attention, encoder_lstm, decoder_lstm, decoder_dense = build_attention_model(attention, batch_size, rnn_units)

# %%
#training
train_test(model_attention, X_train, y_train , X_test,
           y_test, batch_size=batch_size, epochs=200, patience=50)
# Out:
# Epoch 1/200
# 18/18 [==============================] - 162s 2s/step - loss: 2.9645 - accuracy: 0.0531 - val_loss: 2.9467 - val_accuracy: 0.0566
# Epoch 2/200
# 18/18 [==============================] - 5s 288ms/step - loss: 2.9452 - accuracy: 0.0564 - val_loss: 2.9431 - val_accuracy: 0.0622
# Epoch 3/200
# 18/18 [==============================] - 5s 290ms/step - loss: 2.9403 - accuracy: 0.0629 - val_loss: 2.9344 - val_accuracy: 0.0693
# Epoch 4/200
# 18/18 [==============================] - 5s 292ms/step - loss: 2.9363 - accuracy: 0.0684 - val_loss: 2.9311 - val_accuracy: 0.0738
# Epoch 5/200
# 18/18 [==============================] - 5s 294ms/step - loss: 2.9301 - accuracy: 0.0729 - val_loss: 2.9249 - val_accuracy: 0.0755
# Epoch 6/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.9236 - accuracy: 0.0771 - val_loss: 2.9166 - val_accuracy: 0.0817
# Epoch 7/200
# 18/18 [==============================] - 5s 285ms/step - loss: 2.9162 - accuracy: 0.0825 - val_loss: 2.9116 - val_accuracy: 0.0844
# Epoch 8/200
# 18/18 [==============================] - 5s 283ms/step - loss: 2.9075 - accuracy: 0.0868 - val_loss: 2.9047 - val_accuracy: 0.0904
# Epoch 9/200
# 18/18 [==============================] - 5s 283ms/step - loss: 2.8992 - accuracy: 0.0898 - val_loss: 2.8949 - val_accuracy: 0.0909
# Epoch 10/200
# 18/18 [==============================] - 5s 281ms/step - loss: 2.8884 - accuracy: 0.0938 - val_loss: 2.8867 - val_accuracy: 0.0957
# Epoch 11/200
# 18/18 [==============================] - 5s 287ms/step - loss: 2.8774 - accuracy: 0.0989 - val_loss: 2.8711 - val_accuracy: 0.1033
# Epoch 12/200
# 18/18 [==============================] - 5s 288ms/step - loss: 2.8626 - accuracy: 0.1037 - val_loss: 2.8519 - val_accuracy: 0.1095
# Epoch 13/200
# 18/18 [==============================] - 5s 288ms/step - loss: 2.8345 - accuracy: 0.1144 - val_loss: 2.8109 - val_accuracy: 0.1252
# Epoch 14/200
# 18/18 [==============================] - 5s 288ms/step - loss: 2.7862 - accuracy: 0.1317 - val_loss: 2.7626 - val_accuracy: 0.1375
# Epoch 15/200
# 18/18 [==============================] - 5s 288ms/step - loss: 2.7480 - accuracy: 0.1438 - val_loss: 2.7015 - val_accuracy: 0.1558
# Epoch 16/200
# 18/18 [==============================] - 5s 282ms/step - loss: 2.6773 - accuracy: 0.1619 - val_loss: 2.6691 - val_accuracy: 0.1641
# Epoch 17/200
# 18/18 [==============================] - 5s 288ms/step - loss: 2.6150 - accuracy: 0.1793 - val_loss: 2.6826 - val_accuracy: 0.1580
# Epoch 18/200
# 18/18 [==============================] - 5s 289ms/step - loss: 2.6071 - accuracy: 0.1803 - val_loss: 2.5305 - val_accuracy: 0.2014
# Epoch 19/200
# 18/18 [==============================] - 5s 283ms/step - loss: 2.5347 - accuracy: 0.1974 - val_loss: 2.5265 - val_accuracy: 0.1976
# Epoch 20/200
# 18/18 [==============================] - 5s 283ms/step - loss: 2.4585 - accuracy: 0.2153 - val_loss: 2.4618 - val_accuracy: 0.2142
# Epoch 21/200
# 18/18 [==============================] - 5s 284ms/step - loss: 2.4007 - accuracy: 0.2275 - val_loss: 2.4556 - val_accuracy: 0.2137
# Epoch 22/200
# 18/18 [==============================] - 5s 291ms/step - loss: 2.3699 - accuracy: 0.2344 - val_loss: 2.3095 - val_accuracy: 0.2502
# Epoch 23/200
# 18/18 [==============================] - 5s 290ms/step - loss: 2.4397 - accuracy: 0.2155 - val_loss: 2.3673 - val_accuracy: 0.2366
# Epoch 24/200
# 18/18 [==============================] - 5s 284ms/step - loss: 2.2931 - accuracy: 0.2513 - val_loss: 2.2235 - val_accuracy: 0.2681
# Epoch 25/200
# 18/18 [==============================] - 5s 290ms/step - loss: 2.2042 - accuracy: 0.2689 - val_loss: 2.1597 - val_accuracy: 0.2797
# Epoch 26/200
# 18/18 [==============================] - 5s 289ms/step - loss: 2.3398 - accuracy: 0.2347 - val_loss: 2.2104 - val_accuracy: 0.2732
# Epoch 27/200
# 18/18 [==============================] - 5s 289ms/step - loss: 2.1706 - accuracy: 0.2745 - val_loss: 2.0961 - val_accuracy: 0.2944
# Epoch 28/200
# 18/18 [==============================] - 5s 282ms/step - loss: 2.0673 - accuracy: 0.2967 - val_loss: 2.0262 - val_accuracy: 0.3078
# Epoch 29/200
# 18/18 [==============================] - 5s 289ms/step - loss: 2.0410 - accuracy: 0.3001 - val_loss: 2.0550 - val_accuracy: 0.2969
# Epoch 30/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.9939 - accuracy: 0.3087 - val_loss: 1.9172 - val_accuracy: 0.3292
# Epoch 31/200
# 18/18 [==============================] - 5s 294ms/step - loss: 1.9469 - accuracy: 0.3187 - val_loss: 1.8658 - val_accuracy: 0.3423
# Epoch 32/200
# 18/18 [==============================] - 5s 282ms/step - loss: 1.8820 - accuracy: 0.3322 - val_loss: 1.8603 - val_accuracy: 0.3402
# Epoch 33/200
# 18/18 [==============================] - 5s 290ms/step - loss: 1.8595 - accuracy: 0.3369 - val_loss: 1.8427 - val_accuracy: 0.3359
# Epoch 34/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.8798 - accuracy: 0.3293 - val_loss: 2.0601 - val_accuracy: 0.2708
# Epoch 35/200
# 18/18 [==============================] - 5s 281ms/step - loss: 2.5851 - accuracy: 0.1922 - val_loss: 2.6631 - val_accuracy: 0.1642
# Epoch 36/200
# 18/18 [==============================] - 5s 283ms/step - loss: 2.5257 - accuracy: 0.1981 - val_loss: 2.3809 - val_accuracy: 0.2370
# Epoch 37/200
# 18/18 [==============================] - 5s 283ms/step - loss: 2.2397 - accuracy: 0.2683 - val_loss: 2.1061 - val_accuracy: 0.2940
# Epoch 38/200
# 18/18 [==============================] - 5s 290ms/step - loss: 2.0782 - accuracy: 0.2906 - val_loss: 1.9477 - val_accuracy: 0.3227
# Epoch 39/200
# 18/18 [==============================] - 5s 290ms/step - loss: 1.9042 - accuracy: 0.3292 - val_loss: 1.8291 - val_accuracy: 0.3467
# Epoch 40/200
# 18/18 [==============================] - 5s 290ms/step - loss: 1.7626 - accuracy: 0.3636 - val_loss: 1.7719 - val_accuracy: 0.3601
# Epoch 41/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.7254 - accuracy: 0.3692 - val_loss: 1.6357 - val_accuracy: 0.3938
# Epoch 42/200
# 18/18 [==============================] - 5s 283ms/step - loss: 1.6438 - accuracy: 0.3911 - val_loss: 1.6318 - val_accuracy: 0.3935
# Epoch 43/200
# 18/18 [==============================] - 5s 290ms/step - loss: 1.5730 - accuracy: 0.4140 - val_loss: 1.4873 - val_accuracy: 0.4492
# Epoch 44/200
# 18/18 [==============================] - 5s 290ms/step - loss: 1.5693 - accuracy: 0.4123 - val_loss: 1.4508 - val_accuracy: 0.4572
# Epoch 45/200
# 18/18 [==============================] - 5s 290ms/step - loss: 1.4924 - accuracy: 0.4412 - val_loss: 1.4884 - val_accuracy: 0.4286
# Epoch 46/200
# 18/18 [==============================] - 5s 284ms/step - loss: 1.6053 - accuracy: 0.3938 - val_loss: 1.4243 - val_accuracy: 0.4648
# Epoch 47/200
# 18/18 [==============================] - 5s 291ms/step - loss: 1.4005 - accuracy: 0.4749 - val_loss: 1.3694 - val_accuracy: 0.4832
# Epoch 48/200
# 18/18 [==============================] - 5s 290ms/step - loss: 1.3674 - accuracy: 0.4779 - val_loss: 1.2650 - val_accuracy: 0.5242
# Epoch 49/200
# 18/18 [==============================] - 5s 290ms/step - loss: 1.3438 - accuracy: 0.4877 - val_loss: 1.6102 - val_accuracy: 0.3942
# Epoch 50/200
# 18/18 [==============================] - 5s 282ms/step - loss: 1.3040 - accuracy: 0.5021 - val_loss: 1.2872 - val_accuracy: 0.5063
# Epoch 51/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.3001 - accuracy: 0.4953 - val_loss: 1.1574 - val_accuracy: 0.5681
# Epoch 52/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.2546 - accuracy: 0.5159 - val_loss: 1.4715 - val_accuracy: 0.4134
# Epoch 53/200
# 18/18 [==============================] - 5s 283ms/step - loss: 1.2279 - accuracy: 0.5270 - val_loss: 1.1567 - val_accuracy: 0.5537
# Epoch 54/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.1367 - accuracy: 0.5683 - val_loss: 1.0620 - val_accuracy: 0.6085
# Epoch 55/200
# 18/18 [==============================] - 5s 283ms/step - loss: 1.1050 - accuracy: 0.5859 - val_loss: 1.0452 - val_accuracy: 0.6034
# Epoch 56/200
# 18/18 [==============================] - 5s 283ms/step - loss: 1.0676 - accuracy: 0.5923 - val_loss: 0.9251 - val_accuracy: 0.6784
# Epoch 57/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.1347 - accuracy: 0.5658 - val_loss: 1.2348 - val_accuracy: 0.4993
# Epoch 58/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.1471 - accuracy: 0.5518 - val_loss: 0.9257 - val_accuracy: 0.6711
# Epoch 59/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.0095 - accuracy: 0.6221 - val_loss: 1.1342 - val_accuracy: 0.5386
# Epoch 60/200
# 18/18 [==============================] - 5s 283ms/step - loss: 0.9516 - accuracy: 0.6445 - val_loss: 1.0496 - val_accuracy: 0.5827
# Epoch 61/200
# 18/18 [==============================] - 5s 290ms/step - loss: 0.9747 - accuracy: 0.6282 - val_loss: 0.8535 - val_accuracy: 0.6972
# Epoch 62/200
# 18/18 [==============================] - 5s 290ms/step - loss: 0.9674 - accuracy: 0.6358 - val_loss: 0.8877 - val_accuracy: 0.6649
# Epoch 63/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.8553 - accuracy: 0.6916 - val_loss: 0.9160 - val_accuracy: 0.6505
# Epoch 64/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.8371 - accuracy: 0.6965 - val_loss: 0.8569 - val_accuracy: 0.6795
# Epoch 65/200
# 18/18 [==============================] - 5s 282ms/step - loss: 1.2690 - accuracy: 0.5768 - val_loss: 2.1210 - val_accuracy: 0.2580
# Epoch 66/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.9265 - accuracy: 0.3769 - val_loss: 1.2692 - val_accuracy: 0.5656
# Epoch 67/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.4673 - accuracy: 0.4658 - val_loss: 1.2876 - val_accuracy: 0.4976
# Epoch 68/200
# 18/18 [==============================] - 5s 282ms/step - loss: 1.1272 - accuracy: 0.5820 - val_loss: 0.9783 - val_accuracy: 0.6405
# Epoch 69/200
# 18/18 [==============================] - 5s 282ms/step - loss: 0.9129 - accuracy: 0.6720 - val_loss: 0.8023 - val_accuracy: 0.7197
# Epoch 70/200
# 18/18 [==============================] - 5s 290ms/step - loss: 0.7800 - accuracy: 0.7295 - val_loss: 0.8221 - val_accuracy: 0.6966
# Epoch 71/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.6739 - accuracy: 0.7787 - val_loss: 0.6827 - val_accuracy: 0.7659
# Epoch 72/200
# 18/18 [==============================] - 5s 289ms/step - loss: 2.1879 - accuracy: 0.3700 - val_loss: 3.1275 - val_accuracy: 0.2719
# Epoch 73/200
# 18/18 [==============================] - 5s 282ms/step - loss: 2.9122 - accuracy: 0.2389 - val_loss: 2.5318 - val_accuracy: 0.2868
# Epoch 74/200
# 18/18 [==============================] - 5s 289ms/step - loss: 2.4078 - accuracy: 0.3292 - val_loss: 2.2952 - val_accuracy: 0.3794
# Epoch 75/200
# 18/18 [==============================] - 5s 282ms/step - loss: 2.2175 - accuracy: 0.3931 - val_loss: 2.1368 - val_accuracy: 0.4068
# Epoch 76/200
# 18/18 [==============================] - 5s 285ms/step - loss: 2.0742 - accuracy: 0.4210 - val_loss: 2.0130 - val_accuracy: 0.4251
# Epoch 77/200
# 18/18 [==============================] - 5s 300ms/step - loss: 1.9815 - accuracy: 0.4200 - val_loss: 1.9278 - val_accuracy: 0.4304
# Epoch 78/200
# 18/18 [==============================] - 5s 288ms/step - loss: 1.8915 - accuracy: 0.4357 - val_loss: 1.8223 - val_accuracy: 0.4558
# Epoch 79/200
# 18/18 [==============================] - 5s 282ms/step - loss: 1.7973 - accuracy: 0.4639 - val_loss: 1.7734 - val_accuracy: 0.4668
# Epoch 80/200
# 18/18 [==============================] - 5s 282ms/step - loss: 1.8691 - accuracy: 0.4156 - val_loss: 2.2731 - val_accuracy: 0.2280
# Epoch 81/200
# 18/18 [==============================] - 5s 282ms/step - loss: 2.1302 - accuracy: 0.3160 - val_loss: 2.1378 - val_accuracy: 0.2887
# Epoch 82/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.5927 - accuracy: 0.5074 - val_loss: 1.3670 - val_accuracy: 0.6048
# Epoch 83/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.7808 - accuracy: 0.4570 - val_loss: 2.3359 - val_accuracy: 0.3184
# Epoch 84/200
# 18/18 [==============================] - 5s 282ms/step - loss: 1.7254 - accuracy: 0.4441 - val_loss: 1.4619 - val_accuracy: 0.4975
# Epoch 85/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.0814 - accuracy: 0.6677 - val_loss: 0.8911 - val_accuracy: 0.7257
# Epoch 86/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.8573 - accuracy: 0.7157 - val_loss: 0.9853 - val_accuracy: 0.6242
# Epoch 87/200
# 18/18 [==============================] - 5s 282ms/step - loss: 1.2319 - accuracy: 0.5673 - val_loss: 1.2514 - val_accuracy: 0.5300
# Epoch 88/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.0391 - accuracy: 0.6251 - val_loss: 0.7633 - val_accuracy: 0.7495
# Epoch 89/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.6855 - accuracy: 0.7797 - val_loss: 0.5651 - val_accuracy: 0.8381
# Epoch 90/200
# 18/18 [==============================] - 5s 288ms/step - loss: 0.5581 - accuracy: 0.8339 - val_loss: 0.8845 - val_accuracy: 0.6737
# Epoch 91/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.6324 - accuracy: 0.4749 - val_loss: 1.4407 - val_accuracy: 0.4617
# Epoch 92/200
# 18/18 [==============================] - 5s 282ms/step - loss: 0.8020 - accuracy: 0.7272 - val_loss: 0.6071 - val_accuracy: 0.8316
# Epoch 93/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.6367 - accuracy: 0.7919 - val_loss: 2.2935 - val_accuracy: 0.3097
# Epoch 94/200
# 18/18 [==============================] - 5s 289ms/step - loss: 3.2548 - accuracy: 0.2299 - val_loss: 2.6938 - val_accuracy: 0.2245
# Epoch 95/200
# 18/18 [==============================] - 5s 289ms/step - loss: 2.3994 - accuracy: 0.2917 - val_loss: 2.1476 - val_accuracy: 0.3555
# Epoch 96/200
# 18/18 [==============================] - 5s 289ms/step - loss: 2.0185 - accuracy: 0.3964 - val_loss: 1.8799 - val_accuracy: 0.4324
# Epoch 97/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.7384 - accuracy: 0.4789 - val_loss: 1.6039 - val_accuracy: 0.5212
# Epoch 98/200
# 18/18 [==============================] - 5s 282ms/step - loss: 1.4519 - accuracy: 0.5593 - val_loss: 1.2484 - val_accuracy: 0.5961
# Epoch 99/200
# 18/18 [==============================] - 5s 283ms/step - loss: 0.9041 - accuracy: 0.7289 - val_loss: 0.6125 - val_accuracy: 0.8484
# Epoch 100/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.3952 - accuracy: 0.5514 - val_loss: 1.4886 - val_accuracy: 0.4427
# Epoch 101/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.9755 - accuracy: 0.6649 - val_loss: 0.7234 - val_accuracy: 0.7874
# Epoch 102/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.8913 - accuracy: 0.7124 - val_loss: 1.1418 - val_accuracy: 0.5423
# Epoch 103/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.9367 - accuracy: 0.3766 - val_loss: 1.1565 - val_accuracy: 0.5863
# Epoch 104/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.9364 - accuracy: 0.6815 - val_loss: 0.7450 - val_accuracy: 0.7511
# Epoch 105/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.6254 - accuracy: 0.8060 - val_loss: 0.4465 - val_accuracy: 0.8913
# Epoch 106/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.3853 - accuracy: 0.9100 - val_loss: 0.8428 - val_accuracy: 0.7181
# Epoch 107/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.9317 - accuracy: 0.4397 - val_loss: 1.8462 - val_accuracy: 0.3965
# Epoch 108/200
# 18/18 [==============================] - 5s 290ms/step - loss: 1.3448 - accuracy: 0.5157 - val_loss: 1.0418 - val_accuracy: 0.6344
# Epoch 109/200
# 18/18 [==============================] - 5s 290ms/step - loss: 0.6802 - accuracy: 0.7986 - val_loss: 0.4735 - val_accuracy: 0.8907
# Epoch 110/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.4900 - accuracy: 0.8583 - val_loss: 0.4784 - val_accuracy: 0.8603
# Epoch 111/200
# 18/18 [==============================] - 5s 282ms/step - loss: 1.1805 - accuracy: 0.6301 - val_loss: 2.2753 - val_accuracy: 0.3978
# Epoch 112/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.8149 - accuracy: 0.4109 - val_loss: 1.1642 - val_accuracy: 0.5660
# Epoch 113/200
# 18/18 [==============================] - 5s 282ms/step - loss: 0.9970 - accuracy: 0.6374 - val_loss: 0.8947 - val_accuracy: 0.6687
# Epoch 114/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.6130 - accuracy: 0.8135 - val_loss: 0.4602 - val_accuracy: 0.8685
# Epoch 115/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.3391 - accuracy: 0.9248 - val_loss: 0.2919 - val_accuracy: 0.9355
# Epoch 116/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.5309 - accuracy: 0.8740 - val_loss: 2.0864 - val_accuracy: 0.3522
# Epoch 117/200
# 18/18 [==============================] - 5s 283ms/step - loss: 2.4574 - accuracy: 0.3561 - val_loss: 2.0022 - val_accuracy: 0.3580
# Epoch 118/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.7060 - accuracy: 0.4294 - val_loss: 1.5453 - val_accuracy: 0.4922
# Epoch 119/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.4113 - accuracy: 0.4991 - val_loss: 1.0293 - val_accuracy: 0.6435
# Epoch 120/200
# 18/18 [==============================] - 5s 282ms/step - loss: 0.7688 - accuracy: 0.7691 - val_loss: 0.6046 - val_accuracy: 0.8331
# Epoch 121/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.5154 - accuracy: 0.8611 - val_loss: 0.5205 - val_accuracy: 0.8387
# Epoch 122/200
# 18/18 [==============================] - 5s 282ms/step - loss: 1.7490 - accuracy: 0.4784 - val_loss: 2.0613 - val_accuracy: 0.3263
# Epoch 123/200
# 18/18 [==============================] - 5s 282ms/step - loss: 1.3296 - accuracy: 0.5380 - val_loss: 0.8749 - val_accuracy: 0.6705
# Epoch 124/200
# 18/18 [==============================] - 5s 293ms/step - loss: 0.6506 - accuracy: 0.7994 - val_loss: 0.4665 - val_accuracy: 0.8824
# Epoch 125/200
# 18/18 [==============================] - 5s 293ms/step - loss: 0.3558 - accuracy: 0.9291 - val_loss: 0.2862 - val_accuracy: 0.9465
# Epoch 126/200
# 18/18 [==============================] - 5s 290ms/step - loss: 0.2511 - accuracy: 0.9568 - val_loss: 0.2420 - val_accuracy: 0.9529
# Epoch 127/200
# 18/18 [==============================] - 5s 290ms/step - loss: 0.2075 - accuracy: 0.9677 - val_loss: 0.1992 - val_accuracy: 0.9674
# Epoch 128/200
# 18/18 [==============================] - 5s 290ms/step - loss: 0.1808 - accuracy: 0.9739 - val_loss: 0.1865 - val_accuracy: 0.9679
# Epoch 129/200
# 18/18 [==============================] - 5s 283ms/step - loss: 0.1593 - accuracy: 0.9788 - val_loss: 0.1614 - val_accuracy: 0.9759
# Epoch 130/200
# 18/18 [==============================] - 5s 282ms/step - loss: 0.1448 - accuracy: 0.9819 - val_loss: 0.1499 - val_accuracy: 0.9779
# Epoch 131/200
# 18/18 [==============================] - 5s 290ms/step - loss: 0.1332 - accuracy: 0.9837 - val_loss: 0.1422 - val_accuracy: 0.9788
# Epoch 132/200
# 18/18 [==============================] - 5s 290ms/step - loss: 0.1235 - accuracy: 0.9853 - val_loss: 0.1348 - val_accuracy: 0.9796
# Epoch 133/200
# 18/18 [==============================] - 5s 290ms/step - loss: 0.1158 - accuracy: 0.9868 - val_loss: 0.1254 - val_accuracy: 0.9826
# Epoch 134/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.3091 - accuracy: 0.6804 - val_loss: 1.4480 - val_accuracy: 0.5675
# Epoch 135/200
# 18/18 [==============================] - 5s 289ms/step - loss: 3.0669 - accuracy: 0.2679 - val_loss: 2.1992 - val_accuracy: 0.3398
# Epoch 136/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.5163 - accuracy: 0.4951 - val_loss: 1.0378 - val_accuracy: 0.6616
# Epoch 137/200
# 18/18 [==============================] - 5s 282ms/step - loss: 0.8476 - accuracy: 0.7308 - val_loss: 0.5043 - val_accuracy: 0.8847
# Epoch 138/200
# 18/18 [==============================] - 5s 282ms/step - loss: 0.6885 - accuracy: 0.7746 - val_loss: 0.3924 - val_accuracy: 0.9012
# Epoch 139/200
# 18/18 [==============================] - 5s 282ms/step - loss: 0.4151 - accuracy: 0.8852 - val_loss: 2.9112 - val_accuracy: 0.3410
# Epoch 140/200
# 18/18 [==============================] - 5s 290ms/step - loss: 2.3086 - accuracy: 0.3906 - val_loss: 1.2251 - val_accuracy: 0.5738
# Epoch 141/200
# 18/18 [==============================] - 5s 283ms/step - loss: 0.9498 - accuracy: 0.6819 - val_loss: 0.6141 - val_accuracy: 0.8168
# Epoch 142/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.4219 - accuracy: 0.9022 - val_loss: 0.2961 - val_accuracy: 0.9406
# Epoch 143/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.2278 - accuracy: 0.9651 - val_loss: 0.2040 - val_accuracy: 0.9651
# Epoch 144/200
# 18/18 [==============================] - 5s 282ms/step - loss: 0.4624 - accuracy: 0.9121 - val_loss: 4.2867 - val_accuracy: 0.2471
# Epoch 145/200
# 18/18 [==============================] - 5s 289ms/step - loss: 3.5163 - accuracy: 0.2261 - val_loss: 2.7511 - val_accuracy: 0.2728
# Epoch 146/200
# 18/18 [==============================] - 5s 282ms/step - loss: 2.5193 - accuracy: 0.3009 - val_loss: 2.3327 - val_accuracy: 0.3182
# Epoch 147/200
# 18/18 [==============================] - 5s 282ms/step - loss: 2.1213 - accuracy: 0.3810 - val_loss: 1.9268 - val_accuracy: 0.4351
# Epoch 148/200
# 18/18 [==============================] - 5s 282ms/step - loss: 1.8151 - accuracy: 0.4588 - val_loss: 1.7009 - val_accuracy: 0.5013
# Epoch 149/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.7081 - accuracy: 0.4945 - val_loss: 1.6714 - val_accuracy: 0.5025
# Epoch 150/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.6076 - accuracy: 0.5221 - val_loss: 1.5490 - val_accuracy: 0.5359
# Epoch 151/200
# 18/18 [==============================] - 5s 283ms/step - loss: 1.5159 - accuracy: 0.5471 - val_loss: 1.4874 - val_accuracy: 0.5493
# Epoch 152/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.4239 - accuracy: 0.5740 - val_loss: 1.3118 - val_accuracy: 0.6045
# Epoch 153/200
# 18/18 [==============================] - 5s 282ms/step - loss: 0.8988 - accuracy: 0.7239 - val_loss: 1.2651 - val_accuracy: 0.5968
# Epoch 154/200
# 18/18 [==============================] - 5s 282ms/step - loss: 1.1573 - accuracy: 0.6948 - val_loss: 3.0865 - val_accuracy: 0.2662
# Epoch 155/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.9706 - accuracy: 0.4370 - val_loss: 1.3217 - val_accuracy: 0.5446
# Epoch 156/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.8421 - accuracy: 0.7363 - val_loss: 0.7352 - val_accuracy: 0.7534
# Epoch 157/200
# 18/18 [==============================] - 5s 283ms/step - loss: 0.3845 - accuracy: 0.9178 - val_loss: 0.2556 - val_accuracy: 0.9576
# Epoch 158/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.5384 - accuracy: 0.8649 - val_loss: 1.4969 - val_accuracy: 0.5264
# Epoch 159/200
# 18/18 [==============================] - 5s 290ms/step - loss: 2.7532 - accuracy: 0.3441 - val_loss: 2.4698 - val_accuracy: 0.3160
# Epoch 160/200
# 18/18 [==============================] - 5s 282ms/step - loss: 1.7909 - accuracy: 0.4362 - val_loss: 1.1034 - val_accuracy: 0.6272
# Epoch 161/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.8261 - accuracy: 0.7521 - val_loss: 0.5942 - val_accuracy: 0.8479
# Epoch 162/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.4352 - accuracy: 0.9016 - val_loss: 0.5246 - val_accuracy: 0.8545
# Epoch 163/200
# 18/18 [==============================] - 5s 283ms/step - loss: 2.2320 - accuracy: 0.4491 - val_loss: 1.8974 - val_accuracy: 0.4013
# Epoch 164/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.1133 - accuracy: 0.6351 - val_loss: 0.6725 - val_accuracy: 0.7927
# Epoch 165/200
# 18/18 [==============================] - 5s 290ms/step - loss: 0.4409 - accuracy: 0.9062 - val_loss: 0.3240 - val_accuracy: 0.9419
# Epoch 166/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.2346 - accuracy: 0.9683 - val_loss: 0.2075 - val_accuracy: 0.9699
# Epoch 167/200
# 18/18 [==============================] - 5s 288ms/step - loss: 0.1683 - accuracy: 0.9806 - val_loss: 0.1661 - val_accuracy: 0.9790
# Epoch 168/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.1431 - accuracy: 0.9846 - val_loss: 0.1384 - val_accuracy: 0.9842
# Epoch 169/200
# 18/18 [==============================] - 5s 284ms/step - loss: 0.1264 - accuracy: 0.9874 - val_loss: 0.1505 - val_accuracy: 0.9774
# Epoch 170/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.1137 - accuracy: 0.9896 - val_loss: 0.1277 - val_accuracy: 0.9839
# Epoch 171/200
# 18/18 [==============================] - 5s 285ms/step - loss: 0.4507 - accuracy: 0.9015 - val_loss: 1.7701 - val_accuracy: 0.5085
# Epoch 172/200
# 18/18 [==============================] - 5s 294ms/step - loss: 0.9750 - accuracy: 0.7083 - val_loss: 0.7436 - val_accuracy: 0.7571
# Epoch 173/200
# 18/18 [==============================] - 5s 283ms/step - loss: 1.1406 - accuracy: 0.6569 - val_loss: 0.7082 - val_accuracy: 0.7732
# Epoch 174/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.4577 - accuracy: 0.8729 - val_loss: 0.2621 - val_accuracy: 0.9504
# Epoch 175/200
# 18/18 [==============================] - 5s 289ms/step - loss: 0.2087 - accuracy: 0.9650 - val_loss: 0.3272 - val_accuracy: 0.9269
# Epoch 176/200
# 18/18 [==============================] - 5s 290ms/step - loss: 1.1464 - accuracy: 0.7750 - val_loss: 3.7825 - val_accuracy: 0.2742
# Epoch 177/200
# 18/18 [==============================] - 5s 282ms/step - loss: 3.2890 - accuracy: 0.3154 - val_loss: 2.6941 - val_accuracy: 0.3851
# Epoch 178/200
# 18/18 [==============================] - 5s 283ms/step - loss: 2.4571 - accuracy: 0.4046 - val_loss: 2.2683 - val_accuracy: 0.4293
# Epoch 179/200
# 18/18 [==============================] - 5s 283ms/step - loss: 2.2200 - accuracy: 0.4343 - val_loss: 2.1447 - val_accuracy: 0.4462
# Epoch 180/200
# 18/18 [==============================] - 5s 290ms/step - loss: 2.1755 - accuracy: 0.4341 - val_loss: 2.6532 - val_accuracy: 0.2922
# Epoch 181/200
# 18/18 [==============================] - 5s 289ms/step - loss: 3.0299 - accuracy: 0.1366 - val_loss: 2.8637 - val_accuracy: 0.1533
# Epoch 182/200
# 18/18 [==============================] - 5s 283ms/step - loss: 2.4197 - accuracy: 0.2565 - val_loss: 2.1016 - val_accuracy: 0.3437
# Epoch 183/200
# 18/18 [==============================] - 5s 289ms/step - loss: 1.8413 - accuracy: 0.4616 - val_loss: 1.6388 - val_accuracy: 0.5299
# 20/20 [==============================] - 2s 100ms/step - loss: 0.1189 - accuracy: 0.9860
# 2/2 [==============================] - 0s 98ms/step - loss: 0.1269 - accuracy: 0.9838
#
# PREDICTION ACCURACY (%):
# Train: 98.599, Test: 98.375

# %% [markdown]
# # Bahdanau Attention and Luong General Attention implementation

# %% [markdown]
# ## Definition

# %%
class BahdanauAttention(tf.keras.layers.Layer):
    
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()

        # Initialization -------------------------------------------------------
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)       # Single hidden layer network model


    def call(self, query, values):

        query_with_time_axis = tf.expand_dims(query, 1)

        # Score and attention weights ------------------------------------------
        score = self.V(tf.nn.tanh(self.W1(query_with_time_axis) + self.W2(values)))       # Compute score using Bahnadau's score formula
        attention_weights = tf.nn.softmax(score, axis=1)      # Normalize the score 
        
        # Context vector -------------------------------------------------------
        context_vector = attention_weights * values           # Context vector
        context_vector = tf.reduce_sum(context_vector, axis=1)


        return context_vector, attention_weights

# %%
class LuongGeneralAttention(tf.keras.layers.Layer):
    def __init__(self, units):
        super(LuongGeneralAttention, self).__init__()
        
        # Initialization -------------------------------------------------------
        self.W = tf.keras.layers.Dense(units)
        

    def call(self, query, values):
        query_with_time_axis = tf.expand_dims(query, 1)
        values_transposed = tf.transpose(values, perm=[0, 2, 1])

        # Score and attention weights ------------------------------------------
        score = tf.transpose(tf.matmul(query_with_time_axis, self.W(values_transposed)), perm=[0, 2, 1])
        attention_weights = tf.nn.softmax(score, axis=1)

        # Context vector -------------------------------------------------------
        context_vector = attention_weights * values
        context_vector = tf.reduce_sum(context_vector, axis=1)

        return context_vector, attention_weights

# %% [markdown]
# ## Training

# %%
# Train the model using LuongDotAttention 
attention_ld = LuongDotAttention()
model_attention, encoder_lstm_ld, decoder_lstm_ld, decoder_dense_ld = build_attention_model(attention_ld, batch_size, rnn_units)

# %%
train_test(model_attention, X_train, y_train , X_test, y_test, batch_size=batch_size, epochs=200, patience=25)
# Out:
# Epoch 1/200
# 18/18 [==============================] - 166s 2s/step - loss: 2.9634 - accuracy: 0.0529 - val_loss: 2.9467 - val_accuracy: 0.0533
# Epoch 2/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.9452 - accuracy: 0.0581 - val_loss: 2.9444 - val_accuracy: 0.0622
# Epoch 3/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.9418 - accuracy: 0.0626 - val_loss: 2.9405 - val_accuracy: 0.0605
# Epoch 4/200
# 18/18 [==============================] - 5s 287ms/step - loss: 2.9361 - accuracy: 0.0679 - val_loss: 2.9336 - val_accuracy: 0.0703
# Epoch 5/200
# 18/18 [==============================] - 5s 280ms/step - loss: 2.9296 - accuracy: 0.0735 - val_loss: 2.9279 - val_accuracy: 0.0760
# Epoch 6/200
# 18/18 [==============================] - 5s 287ms/step - loss: 2.9212 - accuracy: 0.0805 - val_loss: 2.9192 - val_accuracy: 0.0780
# Epoch 7/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.9126 - accuracy: 0.0842 - val_loss: 2.9120 - val_accuracy: 0.0853
# Epoch 8/200
# 18/18 [==============================] - 5s 279ms/step - loss: 2.9067 - accuracy: 0.0875 - val_loss: 2.9041 - val_accuracy: 0.0863
# Epoch 9/200
# 18/18 [==============================] - 5s 279ms/step - loss: 2.8992 - accuracy: 0.0904 - val_loss: 2.8985 - val_accuracy: 0.0895
# Epoch 10/200
# 18/18 [==============================] - 5s 285ms/step - loss: 2.8905 - accuracy: 0.0932 - val_loss: 2.8845 - val_accuracy: 0.0936
# Epoch 11/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.8772 - accuracy: 0.0986 - val_loss: 2.8632 - val_accuracy: 0.1080
# Epoch 12/200
# 18/18 [==============================] - 5s 285ms/step - loss: 2.8619 - accuracy: 0.1047 - val_loss: 2.8620 - val_accuracy: 0.1061
# Epoch 13/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.8426 - accuracy: 0.1110 - val_loss: 2.8126 - val_accuracy: 0.1205
# Epoch 14/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.7859 - accuracy: 0.1314 - val_loss: 2.7576 - val_accuracy: 0.1406
# Epoch 15/200
# 18/18 [==============================] - 5s 280ms/step - loss: 2.7251 - accuracy: 0.1490 - val_loss: 2.7067 - val_accuracy: 0.1509
# Epoch 16/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.6893 - accuracy: 0.1575 - val_loss: 2.6535 - val_accuracy: 0.1668
# Epoch 17/200
# 18/18 [==============================] - 5s 279ms/step - loss: 2.6237 - accuracy: 0.1750 - val_loss: 2.5731 - val_accuracy: 0.1898
# Epoch 18/200
# 18/18 [==============================] - 5s 279ms/step - loss: 2.5503 - accuracy: 0.1916 - val_loss: 2.5152 - val_accuracy: 0.2006
# Epoch 19/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.5653 - accuracy: 0.1879 - val_loss: 2.5772 - val_accuracy: 0.1853
# Epoch 20/200
# 18/18 [==============================] - 5s 280ms/step - loss: 2.5204 - accuracy: 0.1974 - val_loss: 2.4685 - val_accuracy: 0.2077
# Epoch 21/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.4185 - accuracy: 0.2204 - val_loss: 2.3873 - val_accuracy: 0.2280
# Epoch 22/200
# 18/18 [==============================] - 5s 280ms/step - loss: 2.3480 - accuracy: 0.2360 - val_loss: 2.2935 - val_accuracy: 0.2487
# Epoch 23/200
# 18/18 [==============================] - 5s 280ms/step - loss: 2.3006 - accuracy: 0.2432 - val_loss: 2.2754 - val_accuracy: 0.2521
# Epoch 24/200
# 18/18 [==============================] - 5s 280ms/step - loss: 2.3112 - accuracy: 0.2414 - val_loss: 2.6851 - val_accuracy: 0.1646
# Epoch 25/200
# 18/18 [==============================] - 5s 285ms/step - loss: 2.6331 - accuracy: 0.1707 - val_loss: 2.5108 - val_accuracy: 0.2003
# Epoch 26/200
# 18/18 [==============================] - 5s 279ms/step - loss: 2.3667 - accuracy: 0.2337 - val_loss: 2.2429 - val_accuracy: 0.2616
# Epoch 27/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.2523 - accuracy: 0.2526 - val_loss: 2.2397 - val_accuracy: 0.2564
# Epoch 28/200
# 18/18 [==============================] - 5s 279ms/step - loss: 2.1760 - accuracy: 0.2687 - val_loss: 2.1960 - val_accuracy: 0.2652
# Epoch 29/200
# 18/18 [==============================] - 5s 279ms/step - loss: 2.1204 - accuracy: 0.2778 - val_loss: 2.0427 - val_accuracy: 0.2999
# Epoch 30/200
# 18/18 [==============================] - 5s 285ms/step - loss: 2.0266 - accuracy: 0.3003 - val_loss: 2.1645 - val_accuracy: 0.2677
# Epoch 31/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.0005 - accuracy: 0.3048 - val_loss: 2.0822 - val_accuracy: 0.2848
# Epoch 32/200
# 18/18 [==============================] - 5s 285ms/step - loss: 1.9696 - accuracy: 0.3097 - val_loss: 2.0605 - val_accuracy: 0.2823
# Epoch 33/200
# 18/18 [==============================] - 5s 279ms/step - loss: 1.9438 - accuracy: 0.3141 - val_loss: 1.8635 - val_accuracy: 0.3367
# Epoch 34/200
# 18/18 [==============================] - 5s 280ms/step - loss: 1.8629 - accuracy: 0.3332 - val_loss: 1.8199 - val_accuracy: 0.3449
# Epoch 35/200
# 18/18 [==============================] - 5s 280ms/step - loss: 1.8659 - accuracy: 0.3302 - val_loss: 1.7709 - val_accuracy: 0.3557
# Epoch 36/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.7915 - accuracy: 0.3486 - val_loss: 1.7399 - val_accuracy: 0.3654
# Epoch 37/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.7515 - accuracy: 0.3578 - val_loss: 1.6819 - val_accuracy: 0.3808
# Epoch 38/200
# 18/18 [==============================] - 5s 280ms/step - loss: 1.7437 - accuracy: 0.3587 - val_loss: 1.6722 - val_accuracy: 0.3826
# Epoch 39/200
# 18/18 [==============================] - 5s 279ms/step - loss: 1.7275 - accuracy: 0.3593 - val_loss: 1.6872 - val_accuracy: 0.3730
# Epoch 40/200
# 18/18 [==============================] - 6s 311ms/step - loss: 1.6316 - accuracy: 0.3903 - val_loss: 1.5856 - val_accuracy: 0.4073
# Epoch 41/200
# 18/18 [==============================] - 5s 278ms/step - loss: 1.6559 - accuracy: 0.3806 - val_loss: 1.7333 - val_accuracy: 0.3421
# Epoch 42/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.6048 - accuracy: 0.3933 - val_loss: 1.5418 - val_accuracy: 0.4158
# Epoch 43/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.5513 - accuracy: 0.4099 - val_loss: 1.5160 - val_accuracy: 0.4233
# Epoch 44/200
# 18/18 [==============================] - 5s 285ms/step - loss: 1.5039 - accuracy: 0.4260 - val_loss: 1.4957 - val_accuracy: 0.4301
# Epoch 45/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.4720 - accuracy: 0.4389 - val_loss: 1.4233 - val_accuracy: 0.4492
# Epoch 46/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.4633 - accuracy: 0.4349 - val_loss: 1.3771 - val_accuracy: 0.4691
# Epoch 47/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.3856 - accuracy: 0.4638 - val_loss: 1.3955 - val_accuracy: 0.4612
# Epoch 48/200
# 18/18 [==============================] - 5s 280ms/step - loss: 1.3709 - accuracy: 0.4654 - val_loss: 1.3553 - val_accuracy: 0.4786
# Epoch 49/200
# 18/18 [==============================] - 5s 279ms/step - loss: 1.3352 - accuracy: 0.4848 - val_loss: 1.2880 - val_accuracy: 0.4941
# Epoch 50/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.3059 - accuracy: 0.4915 - val_loss: 1.3432 - val_accuracy: 0.4693
# Epoch 51/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.2589 - accuracy: 0.5101 - val_loss: 1.2439 - val_accuracy: 0.5139
# Epoch 52/200
# 18/18 [==============================] - 5s 280ms/step - loss: 1.2314 - accuracy: 0.5232 - val_loss: 1.3639 - val_accuracy: 0.4510
# Epoch 53/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.5013 - accuracy: 0.4318 - val_loss: 2.0975 - val_accuracy: 0.2921
# Epoch 54/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.9071 - accuracy: 0.1639 - val_loss: 2.8274 - val_accuracy: 0.1310
# Epoch 55/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.5567 - accuracy: 0.1883 - val_loss: 2.4194 - val_accuracy: 0.2202
# Epoch 56/200
# 18/18 [==============================] - 5s 279ms/step - loss: 2.3179 - accuracy: 0.2498 - val_loss: 2.1695 - val_accuracy: 0.2851
# Epoch 57/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.0373 - accuracy: 0.3230 - val_loss: 1.9685 - val_accuracy: 0.3135
# Epoch 58/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.7977 - accuracy: 0.3819 - val_loss: 1.6585 - val_accuracy: 0.4217
# Epoch 59/200
# 18/18 [==============================] - 5s 287ms/step - loss: 1.8658 - accuracy: 0.3521 - val_loss: 2.1421 - val_accuracy: 0.2430
# Epoch 60/200
# 18/18 [==============================] - 5s 279ms/step - loss: 2.6781 - accuracy: 0.1911 - val_loss: 2.2614 - val_accuracy: 0.2621
# Epoch 61/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.9682 - accuracy: 0.3265 - val_loss: 1.6523 - val_accuracy: 0.4135
# Epoch 62/200
# 18/18 [==============================] - 5s 279ms/step - loss: 1.5130 - accuracy: 0.4447 - val_loss: 1.3305 - val_accuracy: 0.4973
# Epoch 63/200
# 18/18 [==============================] - 5s 279ms/step - loss: 1.3959 - accuracy: 0.4568 - val_loss: 1.2179 - val_accuracy: 0.5308
# Epoch 64/200
# 18/18 [==============================] - 5s 280ms/step - loss: 1.2979 - accuracy: 0.4939 - val_loss: 1.2333 - val_accuracy: 0.5243
# Epoch 65/200
# 18/18 [==============================] - 5s 279ms/step - loss: 1.2222 - accuracy: 0.5270 - val_loss: 1.1447 - val_accuracy: 0.5510
# Epoch 66/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.1851 - accuracy: 0.5386 - val_loss: 1.0376 - val_accuracy: 0.6080
# Epoch 67/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.1045 - accuracy: 0.5772 - val_loss: 1.3263 - val_accuracy: 0.4667
# Epoch 68/200
# 18/18 [==============================] - 5s 280ms/step - loss: 1.1983 - accuracy: 0.5387 - val_loss: 1.6082 - val_accuracy: 0.3792
# Epoch 69/200
# 18/18 [==============================] - 5s 279ms/step - loss: 1.1477 - accuracy: 0.5577 - val_loss: 1.0829 - val_accuracy: 0.5918
# Epoch 70/200
# 18/18 [==============================] - 5s 280ms/step - loss: 1.0278 - accuracy: 0.6103 - val_loss: 0.9250 - val_accuracy: 0.6580
# Epoch 71/200
# 18/18 [==============================] - 5s 287ms/step - loss: 1.0339 - accuracy: 0.6108 - val_loss: 0.8609 - val_accuracy: 0.6952
# Epoch 72/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.4635 - accuracy: 0.4732 - val_loss: 1.5523 - val_accuracy: 0.4397
# Epoch 73/200
# 18/18 [==============================] - 5s 279ms/step - loss: 1.3426 - accuracy: 0.4948 - val_loss: 1.0578 - val_accuracy: 0.6058
# Epoch 74/200
# 18/18 [==============================] - 5s 287ms/step - loss: 1.1377 - accuracy: 0.5717 - val_loss: 0.9160 - val_accuracy: 0.6714
# Epoch 75/200
# 18/18 [==============================] - 5s 279ms/step - loss: 1.0587 - accuracy: 0.6019 - val_loss: 0.9398 - val_accuracy: 0.6500
# Epoch 76/200
# 18/18 [==============================] - 5s 287ms/step - loss: 0.9748 - accuracy: 0.6440 - val_loss: 1.3066 - val_accuracy: 0.4864
# Epoch 77/200
# 18/18 [==============================] - 5s 286ms/step - loss: 0.8712 - accuracy: 0.6860 - val_loss: 0.7451 - val_accuracy: 0.7460
# Epoch 78/200
# 18/18 [==============================] - 5s 279ms/step - loss: 0.7550 - accuracy: 0.7411 - val_loss: 0.5841 - val_accuracy: 0.8337
# Epoch 79/200
# 18/18 [==============================] - 5s 286ms/step - loss: 0.7580 - accuracy: 0.7391 - val_loss: 1.6494 - val_accuracy: 0.4294
# Epoch 80/200
# 18/18 [==============================] - 5s 280ms/step - loss: 1.5406 - accuracy: 0.4720 - val_loss: 1.0282 - val_accuracy: 0.6241
# Epoch 81/200
# 18/18 [==============================] - 5s 280ms/step - loss: 1.1489 - accuracy: 0.6037 - val_loss: 1.0742 - val_accuracy: 0.5923
# Epoch 82/200
# 18/18 [==============================] - 5s 286ms/step - loss: 0.9916 - accuracy: 0.6457 - val_loss: 0.7756 - val_accuracy: 0.7613
# Epoch 83/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.2723 - accuracy: 0.6137 - val_loss: 3.3686 - val_accuracy: 0.2313
# Epoch 84/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.1023 - accuracy: 0.4294 - val_loss: 1.6000 - val_accuracy: 0.5092
# Epoch 85/200
# 18/18 [==============================] - 5s 279ms/step - loss: 1.3453 - accuracy: 0.5907 - val_loss: 1.1196 - val_accuracy: 0.6707
# Epoch 86/200
# 18/18 [==============================] - 5s 280ms/step - loss: 1.0055 - accuracy: 0.7050 - val_loss: 0.9235 - val_accuracy: 0.7205
# Epoch 87/200
# 18/18 [==============================] - 5s 279ms/step - loss: 0.8247 - accuracy: 0.7570 - val_loss: 0.7502 - val_accuracy: 0.7833
# Epoch 88/200
# 18/18 [==============================] - 5s 280ms/step - loss: 1.0048 - accuracy: 0.6889 - val_loss: 2.2363 - val_accuracy: 0.4819
# Epoch 89/200
# 18/18 [==============================] - 5s 279ms/step - loss: 1.8744 - accuracy: 0.4440 - val_loss: 1.5332 - val_accuracy: 0.5255
# Epoch 90/200
# 18/18 [==============================] - 5s 280ms/step - loss: 1.0541 - accuracy: 0.6534 - val_loss: 0.8005 - val_accuracy: 0.7398
# Epoch 91/200
# 18/18 [==============================] - 5s 286ms/step - loss: 0.6691 - accuracy: 0.8051 - val_loss: 0.5386 - val_accuracy: 0.8667
# Epoch 92/200
# 18/18 [==============================] - 5s 286ms/step - loss: 0.5310 - accuracy: 0.8595 - val_loss: 0.4537 - val_accuracy: 0.8903
# Epoch 93/200
# 18/18 [==============================] - 5s 286ms/step - loss: 0.4356 - accuracy: 0.8950 - val_loss: 0.3952 - val_accuracy: 0.9058
# Epoch 94/200
# 18/18 [==============================] - 5s 279ms/step - loss: 0.3679 - accuracy: 0.9195 - val_loss: 0.3373 - val_accuracy: 0.9280
# Epoch 95/200
# 18/18 [==============================] - 5s 291ms/step - loss: 0.3011 - accuracy: 0.9427 - val_loss: 0.2731 - val_accuracy: 0.9484
# Epoch 96/200
# 18/18 [==============================] - 5s 288ms/step - loss: 0.2654 - accuracy: 0.9501 - val_loss: 0.8024 - val_accuracy: 0.7696
# Epoch 97/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.2279 - accuracy: 0.4702 - val_loss: 3.9436 - val_accuracy: 0.0793
# Epoch 98/200
# 18/18 [==============================] - 5s 280ms/step - loss: 3.4111 - accuracy: 0.0947 - val_loss: 3.0622 - val_accuracy: 0.1076
# Epoch 99/200
# 18/18 [==============================] - 5s 280ms/step - loss: 2.8937 - accuracy: 0.1194 - val_loss: 2.8264 - val_accuracy: 0.1221
# Epoch 100/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.7890 - accuracy: 0.1405 - val_loss: 2.7634 - val_accuracy: 0.1474
# Epoch 101/200
# 18/18 [==============================] - 5s 279ms/step - loss: 2.7481 - accuracy: 0.1534 - val_loss: 2.7321 - val_accuracy: 0.1560
# Epoch 102/200
# 18/18 [==============================] - 5s 280ms/step - loss: 2.7204 - accuracy: 0.1600 - val_loss: 2.7060 - val_accuracy: 0.1613
# Epoch 103/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.6931 - accuracy: 0.1666 - val_loss: 2.6640 - val_accuracy: 0.1706
# Epoch 104/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.6193 - accuracy: 0.1855 - val_loss: 2.5789 - val_accuracy: 0.1999
# Epoch 105/200
# 18/18 [==============================] - 5s 287ms/step - loss: 2.5472 - accuracy: 0.2091 - val_loss: 2.5189 - val_accuracy: 0.2168
# Epoch 106/200
# 18/18 [==============================] - 5s 280ms/step - loss: 2.4914 - accuracy: 0.2232 - val_loss: 2.4574 - val_accuracy: 0.2315
# Epoch 107/200
# 18/18 [==============================] - 5s 287ms/step - loss: 2.4251 - accuracy: 0.2412 - val_loss: 2.3951 - val_accuracy: 0.2481
# Epoch 108/200
# 18/18 [==============================] - 5s 287ms/step - loss: 2.3632 - accuracy: 0.2552 - val_loss: 2.3309 - val_accuracy: 0.2619
# Epoch 109/200
# 18/18 [==============================] - 5s 287ms/step - loss: 2.2963 - accuracy: 0.2700 - val_loss: 2.2505 - val_accuracy: 0.2797
# Epoch 110/200
# 18/18 [==============================] - 5s 287ms/step - loss: 2.1953 - accuracy: 0.2931 - val_loss: 2.1231 - val_accuracy: 0.3090
# Epoch 111/200
# 18/18 [==============================] - 5s 286ms/step - loss: 2.0627 - accuracy: 0.3243 - val_loss: 1.9823 - val_accuracy: 0.3428
# Epoch 112/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.9437 - accuracy: 0.3427 - val_loss: 1.8922 - val_accuracy: 0.3518
# Epoch 113/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.8522 - accuracy: 0.3561 - val_loss: 1.7452 - val_accuracy: 0.3859
# Epoch 114/200
# 18/18 [==============================] - 5s 280ms/step - loss: 1.7944 - accuracy: 0.3659 - val_loss: 1.6781 - val_accuracy: 0.3966
# Epoch 115/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.8561 - accuracy: 0.3350 - val_loss: 1.6934 - val_accuracy: 0.3716
# Epoch 116/200
# 18/18 [==============================] - 5s 287ms/step - loss: 1.7190 - accuracy: 0.3713 - val_loss: 1.6722 - val_accuracy: 0.4025
# Epoch 117/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.5903 - accuracy: 0.4157 - val_loss: 1.4398 - val_accuracy: 0.4642
# Epoch 118/200
# 18/18 [==============================] - 5s 280ms/step - loss: 1.4423 - accuracy: 0.4670 - val_loss: 1.4146 - val_accuracy: 0.4863
# Epoch 119/200
# 18/18 [==============================] - 5s 286ms/step - loss: 1.6511 - accuracy: 0.4017 - val_loss: 1.8192 - val_accuracy: 0.3568
# Epoch 120/200
# 18/18 [==============================] - 5s 288ms/step - loss: 1.6727 - accuracy: 0.3735 - val_loss: 1.5634 - val_accuracy: 0.3678
# 20/20 [==============================] - 2s 100ms/step - loss: 0.2706 - accuracy: 0.9506
# 2/2 [==============================] - 0s 102ms/step - loss: 0.2833 - accuracy: 0.9435
#
# PREDICTION ACCURACY (%):
# Train: 95.064, Test: 94.345

# %%
# Train the model using BahdanauAttention 
attention_b = BahdanauAttention(rnn_units)
model_attention, encoder_lstm_b, decoder_lstm_b, decoder_dense_b = build_attention_model(attention_b, batch_size, rnn_units)

# %%
train_test(model_attention, X_train, y_train , X_test, y_test, batch_size=batch_size, epochs=200, patience=40)
# Out:
# Epoch 1/200
# 18/18 [==============================] - 179s 3s/step - loss: 2.9647 - accuracy: 0.0553 - val_loss: 2.9473 - val_accuracy: 0.0542
# Epoch 2/200
# 18/18 [==============================] - 14s 776ms/step - loss: 2.9455 - accuracy: 0.0559 - val_loss: 2.9435 - val_accuracy: 0.0545
# Epoch 3/200
# 18/18 [==============================] - 14s 781ms/step - loss: 2.9418 - accuracy: 0.0603 - val_loss: 2.9386 - val_accuracy: 0.0612
# Epoch 4/200
# 18/18 [==============================] - 14s 770ms/step - loss: 2.9355 - accuracy: 0.0676 - val_loss: 2.9325 - val_accuracy: 0.0727
# Epoch 5/200
# 18/18 [==============================] - 14s 774ms/step - loss: 2.9294 - accuracy: 0.0721 - val_loss: 2.9285 - val_accuracy: 0.0710
# Epoch 6/200
# 18/18 [==============================] - 14s 773ms/step - loss: 2.9223 - accuracy: 0.0790 - val_loss: 2.9172 - val_accuracy: 0.0781
# Epoch 7/200
# 18/18 [==============================] - 14s 768ms/step - loss: 2.9107 - accuracy: 0.0838 - val_loss: 2.9064 - val_accuracy: 0.0860
# Epoch 8/200
# 18/18 [==============================] - 14s 774ms/step - loss: 2.9018 - accuracy: 0.0880 - val_loss: 2.8997 - val_accuracy: 0.0885
# Epoch 9/200
# 18/18 [==============================] - 14s 776ms/step - loss: 2.8946 - accuracy: 0.0911 - val_loss: 2.8947 - val_accuracy: 0.0914
# Epoch 10/200
# 18/18 [==============================] - 14s 770ms/step - loss: 2.8870 - accuracy: 0.0933 - val_loss: 2.8842 - val_accuracy: 0.0937
# Epoch 11/200
# 18/18 [==============================] - 14s 775ms/step - loss: 2.8801 - accuracy: 0.0962 - val_loss: 2.8804 - val_accuracy: 0.0949
# Epoch 12/200
# 18/18 [==============================] - 14s 774ms/step - loss: 2.8715 - accuracy: 0.1006 - val_loss: 2.8657 - val_accuracy: 0.1018
# Epoch 13/200
# 18/18 [==============================] - 14s 771ms/step - loss: 2.8555 - accuracy: 0.1052 - val_loss: 2.8482 - val_accuracy: 0.1100
# Epoch 14/200
# 18/18 [==============================] - 14s 776ms/step - loss: 2.8253 - accuracy: 0.1157 - val_loss: 2.8066 - val_accuracy: 0.1210
# Epoch 15/200
# 18/18 [==============================] - 14s 771ms/step - loss: 2.7845 - accuracy: 0.1286 - val_loss: 2.8129 - val_accuracy: 0.1181
# Epoch 16/200
# 18/18 [==============================] - 14s 775ms/step - loss: 2.7540 - accuracy: 0.1378 - val_loss: 2.7182 - val_accuracy: 0.1462
# Epoch 17/200
# 18/18 [==============================] - 14s 775ms/step - loss: 2.6848 - accuracy: 0.1571 - val_loss: 2.6343 - val_accuracy: 0.1742
# Epoch 18/200
# 18/18 [==============================] - 14s 771ms/step - loss: 2.6139 - accuracy: 0.1744 - val_loss: 2.6509 - val_accuracy: 0.1625
# Epoch 19/200
# 18/18 [==============================] - 14s 776ms/step - loss: 2.5575 - accuracy: 0.1883 - val_loss: 2.5100 - val_accuracy: 0.2016
# Epoch 20/200
# 18/18 [==============================] - 14s 776ms/step - loss: 2.5544 - accuracy: 0.1877 - val_loss: 2.6613 - val_accuracy: 0.1645
# Epoch 21/200
# 18/18 [==============================] - 14s 771ms/step - loss: 2.5536 - accuracy: 0.1916 - val_loss: 2.4596 - val_accuracy: 0.2175
# Epoch 22/200
# 18/18 [==============================] - 14s 771ms/step - loss: 2.4310 - accuracy: 0.2171 - val_loss: 2.4518 - val_accuracy: 0.2102
# Epoch 23/200
# 18/18 [==============================] - 14s 771ms/step - loss: 2.3637 - accuracy: 0.2311 - val_loss: 2.3397 - val_accuracy: 0.2379
# Epoch 24/200
# 18/18 [==============================] - 14s 776ms/step - loss: 2.3628 - accuracy: 0.2290 - val_loss: 2.3256 - val_accuracy: 0.2378
# Epoch 25/200
# 18/18 [==============================] - 14s 771ms/step - loss: 2.2756 - accuracy: 0.2491 - val_loss: 2.1919 - val_accuracy: 0.2702
# Epoch 26/200
# 18/18 [==============================] - 14s 771ms/step - loss: 2.2214 - accuracy: 0.2596 - val_loss: 2.1537 - val_accuracy: 0.2769
# Epoch 27/200
# 18/18 [==============================] - 14s 775ms/step - loss: 2.2584 - accuracy: 0.2478 - val_loss: 2.2018 - val_accuracy: 0.2651
# Epoch 28/200
# 18/18 [==============================] - 14s 775ms/step - loss: 2.2366 - accuracy: 0.2536 - val_loss: 2.1117 - val_accuracy: 0.2808
# Epoch 29/200
# 18/18 [==============================] - 14s 776ms/step - loss: 2.0809 - accuracy: 0.2892 - val_loss: 2.0119 - val_accuracy: 0.3078
# Epoch 30/200
# 18/18 [==============================] - 14s 776ms/step - loss: 2.0202 - accuracy: 0.3000 - val_loss: 2.1002 - val_accuracy: 0.2807
# Epoch 31/200
# 18/18 [==============================] - 14s 776ms/step - loss: 1.9623 - accuracy: 0.3122 - val_loss: 2.0077 - val_accuracy: 0.3054
# Epoch 32/200
# 18/18 [==============================] - 14s 777ms/step - loss: 1.9451 - accuracy: 0.3125 - val_loss: 1.9040 - val_accuracy: 0.3307
# Epoch 33/200
# 18/18 [==============================] - 14s 772ms/step - loss: 1.8823 - accuracy: 0.3267 - val_loss: 1.7854 - val_accuracy: 0.3561
# Epoch 34/200
# 18/18 [==============================] - 14s 775ms/step - loss: 2.4062 - accuracy: 0.2248 - val_loss: 2.1009 - val_accuracy: 0.2843
# Epoch 35/200
# 18/18 [==============================] - 14s 771ms/step - loss: 2.0454 - accuracy: 0.3023 - val_loss: 2.0090 - val_accuracy: 0.3072
# Epoch 36/200
# 18/18 [==============================] - 14s 775ms/step - loss: 1.8509 - accuracy: 0.3432 - val_loss: 1.8523 - val_accuracy: 0.3360
# Epoch 37/200
# 18/18 [==============================] - 14s 776ms/step - loss: 1.7309 - accuracy: 0.3665 - val_loss: 1.8992 - val_accuracy: 0.3095
# Epoch 38/200
# 18/18 [==============================] - 14s 771ms/step - loss: 1.7066 - accuracy: 0.3718 - val_loss: 1.7264 - val_accuracy: 0.3599
# Epoch 39/200
# 18/18 [==============================] - 14s 776ms/step - loss: 1.6580 - accuracy: 0.3818 - val_loss: 1.6580 - val_accuracy: 0.3756
# Epoch 40/200
# 18/18 [==============================] - 14s 776ms/step - loss: 1.6098 - accuracy: 0.3956 - val_loss: 1.6448 - val_accuracy: 0.3670
# Epoch 41/200
# 18/18 [==============================] - 14s 771ms/step - loss: 1.5651 - accuracy: 0.4100 - val_loss: 1.6054 - val_accuracy: 0.3683
# Epoch 42/200
# 18/18 [==============================] - 14s 776ms/step - loss: 1.5528 - accuracy: 0.4155 - val_loss: 1.4656 - val_accuracy: 0.4414
# Epoch 43/200
# 18/18 [==============================] - 14s 776ms/step - loss: 2.0272 - accuracy: 0.2942 - val_loss: 1.8678 - val_accuracy: 0.3392
# Epoch 44/200
# 18/18 [==============================] - 14s 770ms/step - loss: 1.7110 - accuracy: 0.3755 - val_loss: 1.6817 - val_accuracy: 0.3614
# Epoch 45/200
# 18/18 [==============================] - 14s 776ms/step - loss: 1.5197 - accuracy: 0.4263 - val_loss: 1.3803 - val_accuracy: 0.5013
# Epoch 46/200
# 18/18 [==============================] - 14s 775ms/step - loss: 1.4506 - accuracy: 0.4448 - val_loss: 1.4275 - val_accuracy: 0.4597
# Epoch 47/200
# 18/18 [==============================] - 14s 770ms/step - loss: 1.3793 - accuracy: 0.4745 - val_loss: 1.2646 - val_accuracy: 0.5296
# Epoch 48/200
# 18/18 [==============================] - 14s 772ms/step - loss: 1.3562 - accuracy: 0.4810 - val_loss: 1.2176 - val_accuracy: 0.5471
# Epoch 49/200
# 18/18 [==============================] - 14s 777ms/step - loss: 1.3103 - accuracy: 0.4987 - val_loss: 1.1912 - val_accuracy: 0.5595
# Epoch 50/200
# 18/18 [==============================] - 14s 770ms/step - loss: 1.9949 - accuracy: 0.3227 - val_loss: 1.8780 - val_accuracy: 0.3109
# Epoch 51/200
# 18/18 [==============================] - 14s 775ms/step - loss: 2.3266 - accuracy: 0.2443 - val_loss: 2.4143 - val_accuracy: 0.2379
# Epoch 52/200
# 18/18 [==============================] - 14s 776ms/step - loss: 1.8951 - accuracy: 0.3409 - val_loss: 1.5167 - val_accuracy: 0.4786
# Epoch 53/200
# 18/18 [==============================] - 14s 777ms/step - loss: 1.4527 - accuracy: 0.4830 - val_loss: 1.4663 - val_accuracy: 0.4555
# Epoch 54/200
# 18/18 [==============================] - 14s 775ms/step - loss: 1.2409 - accuracy: 0.5521 - val_loss: 1.2799 - val_accuracy: 0.4879
# Epoch 55/200
# 18/18 [==============================] - 14s 771ms/step - loss: 1.2051 - accuracy: 0.5373 - val_loss: 1.0118 - val_accuracy: 0.6593
# Epoch 56/200
# 18/18 [==============================] - 14s 775ms/step - loss: 1.1485 - accuracy: 0.5746 - val_loss: 1.0457 - val_accuracy: 0.6086
# Epoch 57/200
# 18/18 [==============================] - 14s 776ms/step - loss: 1.2151 - accuracy: 0.5347 - val_loss: 1.0333 - val_accuracy: 0.6159
# Epoch 58/200
# 18/18 [==============================] - 14s 772ms/step - loss: 1.6775 - accuracy: 0.3870 - val_loss: 2.3537 - val_accuracy: 0.2008
# Epoch 59/200
# 18/18 [==============================] - 14s 771ms/step - loss: 1.6139 - accuracy: 0.3966 - val_loss: 1.2541 - val_accuracy: 0.5149
# Epoch 60/200
# 18/18 [==============================] - 14s 775ms/step - loss: 1.1137 - accuracy: 0.5968 - val_loss: 0.9418 - val_accuracy: 0.7055
# Epoch 61/200
# 18/18 [==============================] - 14s 775ms/step - loss: 1.3616 - accuracy: 0.4668 - val_loss: 1.2479 - val_accuracy: 0.4857
# Epoch 62/200
# 18/18 [==============================] - 14s 770ms/step - loss: 1.1291 - accuracy: 0.5615 - val_loss: 0.9925 - val_accuracy: 0.6288
# Epoch 63/200
# 18/18 [==============================] - 14s 775ms/step - loss: 1.0355 - accuracy: 0.6003 - val_loss: 0.7784 - val_accuracy: 0.7743
# Epoch 64/200
# 18/18 [==============================] - 14s 770ms/step - loss: 1.6322 - accuracy: 0.4546 - val_loss: 2.2752 - val_accuracy: 0.2612
# Epoch 65/200
# 18/18 [==============================] - 14s 770ms/step - loss: 1.7722 - accuracy: 0.3575 - val_loss: 1.3586 - val_accuracy: 0.4758
# Epoch 66/200
# 18/18 [==============================] - 14s 770ms/step - loss: 1.1015 - accuracy: 0.5987 - val_loss: 1.0704 - val_accuracy: 0.5988
# Epoch 67/200
# 18/18 [==============================] - 14s 776ms/step - loss: 0.9385 - accuracy: 0.6631 - val_loss: 0.7662 - val_accuracy: 0.7641
# Epoch 68/200
# 18/18 [==============================] - 14s 775ms/step - loss: 1.0307 - accuracy: 0.6111 - val_loss: 1.1085 - val_accuracy: 0.5915
# Epoch 69/200
# 18/18 [==============================] - 14s 775ms/step - loss: 1.5887 - accuracy: 0.4002 - val_loss: 1.8680 - val_accuracy: 0.2935
# Epoch 70/200
# 18/18 [==============================] - 14s 770ms/step - loss: 1.1451 - accuracy: 0.5558 - val_loss: 0.8073 - val_accuracy: 0.7478
# Epoch 71/200
# 18/18 [==============================] - 14s 769ms/step - loss: 0.8411 - accuracy: 0.7021 - val_loss: 0.9739 - val_accuracy: 0.5984
# Epoch 72/200
# 18/18 [==============================] - 14s 775ms/step - loss: 0.8224 - accuracy: 0.6974 - val_loss: 0.6252 - val_accuracy: 0.8213
# Epoch 73/200
# 18/18 [==============================] - 14s 776ms/step - loss: 1.3826 - accuracy: 0.4840 - val_loss: 1.2596 - val_accuracy: 0.5060
# Epoch 74/200
# 18/18 [==============================] - 14s 775ms/step - loss: 1.0104 - accuracy: 0.5988 - val_loss: 0.8669 - val_accuracy: 0.6892
# Epoch 75/200
# 18/18 [==============================] - 14s 770ms/step - loss: 1.1132 - accuracy: 0.5714 - val_loss: 1.0294 - val_accuracy: 0.5630
# Epoch 76/200
# 18/18 [==============================] - 14s 775ms/step - loss: 1.3081 - accuracy: 0.4772 - val_loss: 0.9382 - val_accuracy: 0.6470
# Epoch 77/200
# 18/18 [==============================] - 14s 770ms/step - loss: 1.0852 - accuracy: 0.5853 - val_loss: 0.8323 - val_accuracy: 0.7026
# Epoch 78/200
# 18/18 [==============================] - 14s 775ms/step - loss: 0.7051 - accuracy: 0.7724 - val_loss: 0.5908 - val_accuracy: 0.8282
# Epoch 79/200
# 18/18 [==============================] - 14s 769ms/step - loss: 1.2471 - accuracy: 0.5857 - val_loss: 0.9481 - val_accuracy: 0.6556
# Epoch 80/200
# 18/18 [==============================] - 14s 770ms/step - loss: 1.6731 - accuracy: 0.4212 - val_loss: 1.3037 - val_accuracy: 0.5104
# Epoch 81/200
# 18/18 [==============================] - 14s 776ms/step - loss: 0.9045 - accuracy: 0.6779 - val_loss: 0.7113 - val_accuracy: 0.7813
# Epoch 82/200
# 18/18 [==============================] - 14s 770ms/step - loss: 0.7231 - accuracy: 0.7539 - val_loss: 0.5193 - val_accuracy: 0.8765
# Epoch 83/200
# 18/18 [==============================] - 14s 770ms/step - loss: 1.5143 - accuracy: 0.5317 - val_loss: 1.7774 - val_accuracy: 0.3893
# Epoch 84/200
# 18/18 [==============================] - 14s 775ms/step - loss: 2.1186 - accuracy: 0.3130 - val_loss: 1.3849 - val_accuracy: 0.4731
# Epoch 85/200
# 18/18 [==============================] - 14s 770ms/step - loss: 2.0241 - accuracy: 0.3024 - val_loss: 1.2486 - val_accuracy: 0.5416
# Epoch 86/200
# 18/18 [==============================] - 14s 775ms/step - loss: 1.1254 - accuracy: 0.5965 - val_loss: 0.8365 - val_accuracy: 0.7729
# Epoch 87/200
# 18/18 [==============================] - 14s 775ms/step - loss: 0.7071 - accuracy: 0.8288 - val_loss: 0.5725 - val_accuracy: 0.8773
# Epoch 88/200
# 18/18 [==============================] - 14s 775ms/step - loss: 0.5693 - accuracy: 0.8469 - val_loss: 0.6493 - val_accuracy: 0.7622
# Epoch 89/200
# 18/18 [==============================] - 14s 770ms/step - loss: 0.9447 - accuracy: 0.6796 - val_loss: 2.0290 - val_accuracy: 0.4221
# Epoch 90/200
# 18/18 [==============================] - 14s 771ms/step - loss: 1.3309 - accuracy: 0.5165 - val_loss: 1.0757 - val_accuracy: 0.6364
# Epoch 91/200
# 18/18 [==============================] - 14s 775ms/step - loss: 0.8550 - accuracy: 0.6738 - val_loss: 0.9498 - val_accuracy: 0.6342
# Epoch 92/200
# 18/18 [==============================] - 14s 775ms/step - loss: 0.9620 - accuracy: 0.6291 - val_loss: 0.5924 - val_accuracy: 0.8216
# Epoch 93/200
# 18/18 [==============================] - 14s 775ms/step - loss: 0.8317 - accuracy: 0.7064 - val_loss: 1.7006 - val_accuracy: 0.3892
# Epoch 94/200
# 18/18 [==============================] - 14s 775ms/step - loss: 1.1670 - accuracy: 0.5481 - val_loss: 0.9000 - val_accuracy: 0.6269
# Epoch 95/200
# 18/18 [==============================] - 14s 770ms/step - loss: 0.5531 - accuracy: 0.8433 - val_loss: 0.4085 - val_accuracy: 0.9193
# Epoch 96/200
# 18/18 [==============================] - 14s 770ms/step - loss: 0.3656 - accuracy: 0.9310 - val_loss: 0.3624 - val_accuracy: 0.9179
# Epoch 97/200
# 18/18 [==============================] - 14s 775ms/step - loss: 1.4664 - accuracy: 0.5144 - val_loss: 1.4748 - val_accuracy: 0.5374
# Epoch 98/200
# 18/18 [==============================] - 14s 774ms/step - loss: 1.1534 - accuracy: 0.5762 - val_loss: 0.8963 - val_accuracy: 0.6899
# Epoch 99/200
# 18/18 [==============================] - 14s 776ms/step - loss: 0.6443 - accuracy: 0.7976 - val_loss: 1.1649 - val_accuracy: 0.5262
# Epoch 100/200
# 18/18 [==============================] - 14s 772ms/step - loss: 0.9213 - accuracy: 0.6317 - val_loss: 0.6221 - val_accuracy: 0.7884
# Epoch 101/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.4189 - accuracy: 0.9053 - val_loss: 0.3242 - val_accuracy: 0.9417
# Epoch 102/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.2865 - accuracy: 0.9537 - val_loss: 0.2570 - val_accuracy: 0.9587
# Epoch 103/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.2304 - accuracy: 0.9656 - val_loss: 0.2207 - val_accuracy: 0.9640
# Epoch 104/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.1974 - accuracy: 0.9716 - val_loss: 0.1892 - val_accuracy: 0.9729
# Epoch 105/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.1721 - accuracy: 0.9767 - val_loss: 0.1665 - val_accuracy: 0.9774
# Epoch 106/200
# 18/18 [==============================] - 14s 772ms/step - loss: 0.1534 - accuracy: 0.9800 - val_loss: 0.1487 - val_accuracy: 0.9808
# Epoch 107/200
# 18/18 [==============================] - 14s 771ms/step - loss: 0.1383 - accuracy: 0.9829 - val_loss: 0.1363 - val_accuracy: 0.9823
# Epoch 108/200
# 18/18 [==============================] - 14s 772ms/step - loss: 0.1244 - accuracy: 0.9853 - val_loss: 0.1222 - val_accuracy: 0.9850
# Epoch 109/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.1126 - accuracy: 0.9873 - val_loss: 0.1116 - val_accuracy: 0.9870
# Epoch 110/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.1032 - accuracy: 0.9888 - val_loss: 0.1043 - val_accuracy: 0.9875
# Epoch 111/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0949 - accuracy: 0.9898 - val_loss: 0.0945 - val_accuracy: 0.9899
# Epoch 112/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0876 - accuracy: 0.9910 - val_loss: 0.0888 - val_accuracy: 0.9903
# Epoch 113/200
# 18/18 [==============================] - 14s 776ms/step - loss: 0.0815 - accuracy: 0.9919 - val_loss: 0.0819 - val_accuracy: 0.9911
# Epoch 114/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0755 - accuracy: 0.9926 - val_loss: 0.0769 - val_accuracy: 0.9926
# Epoch 115/200
# 18/18 [==============================] - 14s 774ms/step - loss: 0.0706 - accuracy: 0.9933 - val_loss: 0.0709 - val_accuracy: 0.9933
# Epoch 116/200
# 18/18 [==============================] - 14s 772ms/step - loss: 0.0654 - accuracy: 0.9941 - val_loss: 0.0658 - val_accuracy: 0.9932
# Epoch 117/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0622 - accuracy: 0.9945 - val_loss: 0.0618 - val_accuracy: 0.9936
# Epoch 118/200
# 18/18 [==============================] - 14s 774ms/step - loss: 0.0579 - accuracy: 0.9950 - val_loss: 0.0586 - val_accuracy: 0.9940
# Epoch 119/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0544 - accuracy: 0.9954 - val_loss: 0.0560 - val_accuracy: 0.9940
# Epoch 120/200
# 18/18 [==============================] - 14s 772ms/step - loss: 0.0508 - accuracy: 0.9959 - val_loss: 0.0515 - val_accuracy: 0.9948
# Epoch 121/200
# 18/18 [==============================] - 14s 772ms/step - loss: 0.0478 - accuracy: 0.9964 - val_loss: 0.0498 - val_accuracy: 0.9949
# Epoch 122/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0453 - accuracy: 0.9966 - val_loss: 0.0465 - val_accuracy: 0.9956
# Epoch 123/200
# 18/18 [==============================] - 14s 772ms/step - loss: 0.0430 - accuracy: 0.9969 - val_loss: 0.0440 - val_accuracy: 0.9960
# Epoch 124/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0410 - accuracy: 0.9970 - val_loss: 0.0417 - val_accuracy: 0.9964
# Epoch 125/200
# 18/18 [==============================] - 14s 772ms/step - loss: 0.0386 - accuracy: 0.9972 - val_loss: 0.0397 - val_accuracy: 0.9967
# Epoch 126/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0366 - accuracy: 0.9975 - val_loss: 0.0378 - val_accuracy: 0.9970
# Epoch 127/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0349 - accuracy: 0.9977 - val_loss: 0.0362 - val_accuracy: 0.9970
# Epoch 128/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0333 - accuracy: 0.9979 - val_loss: 0.0348 - val_accuracy: 0.9974
# Epoch 129/200
# 18/18 [==============================] - 14s 772ms/step - loss: 0.0318 - accuracy: 0.9980 - val_loss: 0.0330 - val_accuracy: 0.9975
# Epoch 130/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0305 - accuracy: 0.9981 - val_loss: 0.0317 - val_accuracy: 0.9975
# Epoch 131/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0292 - accuracy: 0.9982 - val_loss: 0.0303 - val_accuracy: 0.9980
# Epoch 132/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0280 - accuracy: 0.9984 - val_loss: 0.0297 - val_accuracy: 0.9977
# Epoch 133/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0269 - accuracy: 0.9984 - val_loss: 0.0280 - val_accuracy: 0.9981
# Epoch 134/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0257 - accuracy: 0.9985 - val_loss: 0.0269 - val_accuracy: 0.9981
# Epoch 135/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0248 - accuracy: 0.9986 - val_loss: 0.0259 - val_accuracy: 0.9981
# Epoch 136/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0237 - accuracy: 0.9987 - val_loss: 0.0248 - val_accuracy: 0.9982
# Epoch 137/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0229 - accuracy: 0.9988 - val_loss: 0.0241 - val_accuracy: 0.9982
# Epoch 138/200
# 18/18 [==============================] - 14s 772ms/step - loss: 0.0220 - accuracy: 0.9989 - val_loss: 0.0232 - val_accuracy: 0.9984
# Epoch 139/200
# 18/18 [==============================] - 14s 772ms/step - loss: 0.0213 - accuracy: 0.9989 - val_loss: 0.0225 - val_accuracy: 0.9986
# Epoch 140/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0205 - accuracy: 0.9990 - val_loss: 0.0215 - val_accuracy: 0.9984
# Epoch 141/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0198 - accuracy: 0.9990 - val_loss: 0.0208 - val_accuracy: 0.9985
# Epoch 142/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0192 - accuracy: 0.9991 - val_loss: 0.0203 - val_accuracy: 0.9984
# Epoch 143/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0186 - accuracy: 0.9991 - val_loss: 0.0195 - val_accuracy: 0.9986
# Epoch 144/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0179 - accuracy: 0.9992 - val_loss: 0.0189 - val_accuracy: 0.9989
# Epoch 145/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0173 - accuracy: 0.9992 - val_loss: 0.0183 - val_accuracy: 0.9989
# Epoch 146/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0167 - accuracy: 0.9993 - val_loss: 0.0177 - val_accuracy: 0.9987
# Epoch 147/200
# 18/18 [==============================] - 14s 772ms/step - loss: 0.0162 - accuracy: 0.9994 - val_loss: 0.0172 - val_accuracy: 0.9989
# Epoch 148/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0157 - accuracy: 0.9994 - val_loss: 0.0168 - val_accuracy: 0.9990
# Epoch 149/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0152 - accuracy: 0.9995 - val_loss: 0.0163 - val_accuracy: 0.9990
# Epoch 150/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0148 - accuracy: 0.9995 - val_loss: 0.0159 - val_accuracy: 0.9990
# Epoch 151/200
# 18/18 [==============================] - 14s 772ms/step - loss: 0.0144 - accuracy: 0.9995 - val_loss: 0.0155 - val_accuracy: 0.9992
# Epoch 152/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0139 - accuracy: 0.9996 - val_loss: 0.0149 - val_accuracy: 0.9992
# Epoch 153/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0136 - accuracy: 0.9996 - val_loss: 0.0145 - val_accuracy: 0.9992
# Epoch 154/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0131 - accuracy: 0.9996 - val_loss: 0.0141 - val_accuracy: 0.9993
# Epoch 155/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0128 - accuracy: 0.9996 - val_loss: 0.0137 - val_accuracy: 0.9993
# Epoch 156/200
# 18/18 [==============================] - 14s 772ms/step - loss: 0.0124 - accuracy: 0.9996 - val_loss: 0.0133 - val_accuracy: 0.9994
# Epoch 157/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0121 - accuracy: 0.9997 - val_loss: 0.0131 - val_accuracy: 0.9994
# Epoch 158/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0117 - accuracy: 0.9997 - val_loss: 0.0126 - val_accuracy: 0.9995
# Epoch 159/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0114 - accuracy: 0.9997 - val_loss: 0.0124 - val_accuracy: 0.9995
# Epoch 160/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0111 - accuracy: 0.9997 - val_loss: 0.0120 - val_accuracy: 0.9994
# Epoch 161/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0108 - accuracy: 0.9997 - val_loss: 0.0117 - val_accuracy: 0.9996
# Epoch 162/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0106 - accuracy: 0.9997 - val_loss: 0.0115 - val_accuracy: 0.9996
# Epoch 163/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0103 - accuracy: 0.9997 - val_loss: 0.0112 - val_accuracy: 0.9996
# Epoch 164/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0101 - accuracy: 0.9998 - val_loss: 0.0109 - val_accuracy: 0.9997
# Epoch 165/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0098 - accuracy: 0.9998 - val_loss: 0.0107 - val_accuracy: 0.9997
# Epoch 166/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0096 - accuracy: 0.9998 - val_loss: 0.0104 - val_accuracy: 0.9997
# Epoch 167/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0093 - accuracy: 0.9998 - val_loss: 0.0101 - val_accuracy: 0.9997
# Epoch 168/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0091 - accuracy: 0.9998 - val_loss: 0.0100 - val_accuracy: 0.9997
# Epoch 169/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0089 - accuracy: 0.9998 - val_loss: 0.0098 - val_accuracy: 0.9997
# Epoch 170/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0087 - accuracy: 0.9998 - val_loss: 0.0095 - val_accuracy: 0.9997
# Epoch 171/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0085 - accuracy: 0.9998 - val_loss: 0.0093 - val_accuracy: 0.9997
# Epoch 172/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0083 - accuracy: 0.9998 - val_loss: 0.0092 - val_accuracy: 0.9997
# Epoch 173/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0081 - accuracy: 0.9998 - val_loss: 0.0089 - val_accuracy: 0.9997
# Epoch 174/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0079 - accuracy: 0.9998 - val_loss: 0.0087 - val_accuracy: 0.9998
# Epoch 175/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0077 - accuracy: 0.9998 - val_loss: 0.0085 - val_accuracy: 0.9997
# Epoch 176/200
# 18/18 [==============================] - 14s 772ms/step - loss: 0.0076 - accuracy: 0.9998 - val_loss: 0.0083 - val_accuracy: 0.9998
# Epoch 177/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0074 - accuracy: 0.9999 - val_loss: 0.0081 - val_accuracy: 0.9998
# Epoch 178/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0072 - accuracy: 0.9999 - val_loss: 0.0080 - val_accuracy: 0.9998
# Epoch 179/200
# 18/18 [==============================] - 14s 774ms/step - loss: 0.0071 - accuracy: 0.9999 - val_loss: 0.0078 - val_accuracy: 0.9997
# Epoch 180/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0069 - accuracy: 0.9999 - val_loss: 0.0077 - val_accuracy: 0.9998
# Epoch 181/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0068 - accuracy: 0.9999 - val_loss: 0.0075 - val_accuracy: 0.9998
# Epoch 182/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0066 - accuracy: 0.9999 - val_loss: 0.0074 - val_accuracy: 0.9998
# Epoch 183/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0065 - accuracy: 0.9999 - val_loss: 0.0073 - val_accuracy: 0.9998
# Epoch 184/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0064 - accuracy: 0.9999 - val_loss: 0.0072 - val_accuracy: 0.9998
# Epoch 185/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0063 - accuracy: 0.9999 - val_loss: 0.0070 - val_accuracy: 0.9998
# Epoch 186/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0061 - accuracy: 0.9999 - val_loss: 0.0069 - val_accuracy: 0.9998
# Epoch 187/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0060 - accuracy: 0.9999 - val_loss: 0.0067 - val_accuracy: 0.9999
# Epoch 188/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0059 - accuracy: 0.9999 - val_loss: 0.0066 - val_accuracy: 0.9999
# Epoch 189/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0058 - accuracy: 0.9999 - val_loss: 0.0065 - val_accuracy: 0.9999
# Epoch 190/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0057 - accuracy: 0.9999 - val_loss: 0.0063 - val_accuracy: 0.9999
# Epoch 191/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0056 - accuracy: 0.9999 - val_loss: 0.0062 - val_accuracy: 0.9999
# Epoch 192/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 0.9999
# Epoch 193/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0061 - val_accuracy: 0.9999
# Epoch 194/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 0.9999
# Epoch 195/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0058 - val_accuracy: 0.9999
# Epoch 196/200
# 18/18 [==============================] - 14s 778ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 0.9999
# Epoch 197/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9999
# Epoch 198/200
# 18/18 [==============================] - 14s 780ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 0.0055 - val_accuracy: 0.9999
# Epoch 199/200
# 18/18 [==============================] - 14s 773ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 0.9999
# Epoch 200/200
# 18/18 [==============================] - 14s 777ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0053 - val_accuracy: 0.9999
# 20/20 [==============================] - 6s 278ms/step - loss: 0.0047 - accuracy: 1.0000
# 2/2 [==============================] - 1s 284ms/step - loss: 0.0055 - accuracy: 0.9997
#
# PREDICTION ACCURACY (%):
# Train: 99.996, Test: 99.970

# %%
# Train the model using LuongGeneralAttention 
attention_lg = LuongGeneralAttention(rnn_units)
model_attention, encoder_lstm_lg, decoder_lstm_lg, decoder_dense_lg = build_attention_model(attention_lg, batch_size, rnn_units)

# %%
train_test(model_attention, X_train, y_train , X_test, y_test, batch_size=batch_size, epochs=200, patience=25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-42b0584f6386> in <module>
# ----> 1 train_test(model_attention, X_train, y_train , X_test, y_test, batch_size=batch_size, epochs=200, patience=25)
#
# NameError: name 'train_test' is not defined

# %% [markdown]
# # Comparative

# %% [markdown]
# In the following the results of the training of the method using the three different attention mechanisms

# %% [markdown]
# Clearly, the results of the training are subject to some variability, in order to try and reduce it as much as possible, high values of patience, for the early stopping, were chosen. (25 for the Luong attention and 40 for the Bahdanau attention) The observations made are a conclusion of many experiments and training sessions of the models, not only the last performed, which are the ones presented.
#
# In general, after some eperimenting and repeated training of the methods, we can observe that
#
#
# *   The method using Bahdanau attention takes a bit longer to converge to a good enough result (thus the choice for a higher value of the patience parameter)
# *   The method using Bahdanau attention seems, on average, to be performing better than the one using Luong attention (both dot and general)
# *   The method using Luong attention obtains a worse result compared to the other two methods, perhaps due to the necessity of a longer training (which was a bit too demanding in terms of computational time for this specific exercise)
# *   The three methods result in good weight visualization matrix structures

# %% [markdown]
# # Weight Visualization

# %%
def evaluate(seq_in, encoder_lstm, decoder_lstm, decoder_dense, attention):

  # Initialization -------------------------------------------------------------
  attention_plot = np.zeros((n_timesteps_in, n_timesteps_in))
  sequence = one_hot_encode(seq_in,n_features)

  # ENCODER STEP ---------------------------------------------------------------
  encoder_inputs = np.array(sequence).reshape(1,n_timesteps_in,n_features)
  encoder_inputs = tf.convert_to_tensor(encoder_inputs,dtype=tf.float32)
  encoder_outputs, encoder_state_h, encoder_state_c = encoder_lstm(encoder_inputs)

  states = [encoder_state_h, encoder_state_c]

  all_outputs = []

  # DECODER STEP ---------------------------------------------------------------
  decoder_input_data = np.zeros((1, 1, n_features))
  decoder_input_data[:, 0, 0] = 1 
  inputs = decoder_input_data
  decoder_outputs = encoder_state_h

  for t in range(n_timesteps_in):
      # Pay attention
      # Create the context vector by applying attention to the outputs.
      context_vector, attention_weights = attention(decoder_outputs, encoder_outputs)
      context_vector = tf.expand_dims(context_vector, 1)

      # Concatenate the input + context vectore to find the next decoder's input
      inputs = tf.concat([context_vector, inputs], axis=-1)

      # Storing the attention weights to plot later on
      attention_weights = tf.reshape(attention_weights, (-1, ))
      attention_plot[t] = attention_weights.numpy()
      
      # Passing the concatenated vector to the LSTM
      # Run the decoder on one timestep and previous states
      decoder_outputs=tf.expand_dims(decoder_outputs, 1)
      decoder_outputs, encoder_state_h, encoder_state_c = decoder_lstm(inputs, initial_state=states)
      outputs = decoder_dense(decoder_outputs)

      # Use the last hidden state for prediction the output, save the current prediction
      # Predictions will be concatenated later
      outputs = tf.expand_dims(outputs, 1)
      all_outputs.append(outputs)

      # Reinject the outputs as inputs for the next loop iteration as well as update the states
      inputs = outputs
      states = [encoder_state_h, encoder_state_c]

  decoder_outputs = Lambda(lambda x: K.concatenate(x, axis=1))(all_outputs)
  seq_out=one_hot_decode(decoder_outputs[0])
  
  return seq_in, seq_out, attention_plot

# %%
import matplotlib.ticker as ticker

def plot_attention(attention, sequence, predicted_sequence):
  fig = plt.figure(figsize=(16,16))
  ax = fig.add_subplot(1, 1, 1)
  ax.matshow(attention, cmap='viridis')

  # labels ---------------------------------------------------------------------
  fontdict = {'fontsize': 10}
  ax.set_xticklabels([''] + sequence, fontdict=fontdict, rotation=90)
  ax.set_yticklabels([''] + predicted_sequence, fontdict=fontdict)

  ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
  ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

  plt.show()

# %%
def translate(seq_in, encoder_lstm, decoder_lstm, decoder_dense, attention):
  seq_in, seq_out, attention_plot = evaluate(seq_in, encoder_lstm, decoder_lstm, decoder_dense, attention)
  attention_plot = attention_plot[:len(seq_out), :len(seq_in)]
  plot_attention(attention_plot, seq_in, seq_out)

# %%
# Plot for the model using LuongDotAttention -----------------------------------
translate(generate_sequence(n_timesteps_in, n_features), encoder_lstm_ld, decoder_lstm_ld, decoder_dense_ld, attention_ld)

# %%
# Plot for the model using BahdanauAttention -----------------------------------
translate(generate_sequence(n_timesteps_in, n_features), encoder_lstm_b, decoder_lstm_b, decoder_dense_b, attention_b)

# %%
# Plot for the model using LuongGeneralAttention  ------------------------------
translate(generate_sequence(n_timesteps_in, n_features), encoder_lstm_lg, decoder_lstm_lg, decoder_dense_lg, attention_lg)

# %% [markdown]
# # Blog site

# %% [markdown]
# Link to the blog post page: https://hackmd.io/@pZpT2t08QVizsgiFR4pbmQ/BkmVpGsOj

# %% [markdown]
# # Report
#
# + Bahdanau Attention and Luong General Attention implementation.
# + Comparative.
# + Weight visualization.
# + Blog site.
